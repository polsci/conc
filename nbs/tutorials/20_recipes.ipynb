# %%
#| hide
import os

# %%
#| hide
source_path = f'{os.environ.get("HOME")}/data/'  
save_path = f'{os.environ.get("HOME")}/data/conc-test-corpora/'

# %% [markdown]
# # Quick Conc Recipes
#
# > Code snippets for common tasks in Conc.
# - toc: false
# - page-layout: full

# %% [markdown]
# The [Get started with Conc](https://geoffford.nz/conc/tutorials/start.html) tutorial (in progress) is a detailed step through Conc functionality. This page provides simple code recipes for common Conc tasks. See the [Conc API Reference](https://geoffford.nz/conc/api) for information on available methods, functions and parameters.

# %% [markdown]
# ## Install Conc

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Basic install
#
# See the [installation page](https://geoffford.nz/conc/tutorials/install.html) if you have a pre-2013 device, want to install the latest development version, or want to install optional dependencies.

# %% [markdown]
# Conc is tested with Python 3.10+. Create a new environment (with venv, conda or similiar) and run the following command to install Conc in your terminal. If you working within a notebook environment, you can usually run commands in a code cell with an `!` symbol before the command.
# ```bash
# pip install conc
# ```

# %% [markdown]
# The Conc install process installs spaCy, but you will need a spaCy model. Once the package and its dependencies are installed, run the following command to download the English language model for spaCy. If you want to use a different language, consult the [spaCy models](https://spacy.io/models) page for information on available models.
# ```bash
# python -m spacy download en_core_web_sm
# ```

# %% [markdown]
# :::

# %% [markdown]
# ## Building or loading a corpus for analysis

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Build a Conc corpus from text files (or a compressed archive of text files) and prepare to report on it

# %% [markdown]
# The example assumes you've set the `name` and `description` of your corpus, as well as the `path_to_source_file` and `save_path` variables. The `path_to_source_file` can be a directory of text files or a compressed archive of text files (i.e. .zip, .tar.gz).

# %%
#| eval: false
from conc.corpus import Corpus
from conc.conc import Conc

# %%
#| hide
name = 'Garden Party Corpus'
description = 'A corpus of short stories from The Garden Party: and Other Stories by Katherine Mansfield. Texts downloaded from Project Gutenberg https://gutenberg.org/ and are in the public domain. The text files contain the short story without the title. https://github.com/ucdh/scraping-garden-party'
source_file = 'garden-party-corpus.zip'
path_to_source_file = f'{source_path}{source_file}'

# %%
#| eval: false
corpus = Corpus(name=name, description=description).build_from_files(source_path = path_to_source_file, save_path = save_path)
corpus.summary()
conc = Conc(corpus=corpus) # prerequisite for running reports
# Out:
# <div id="aafimvytxu" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #aafimvytxu table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #aafimvytxu thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #aafimvytxu p { margin: 0; padding: 0; }
#  #aafimvytxu .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #aafimvytxu .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #aafimvytxu .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #aafimvytxu .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #aafimvytxu .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #aafimvytxu .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #aafimvytxu .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #aafimvytxu .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #aafimvytxu .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #aafimvytxu .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #aafimvytxu .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #aafimvytxu .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #aafimvytxu .gt_spanner_row { border-bottom-style: hidden; }
#  #aafimvytxu .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #aafimvytxu .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #aafimvytxu .gt_from_md> :first-child { margin-top: 0; }
#  #aafimvytxu .gt_from_md> :last-child { margin-bottom: 0; }
#  #aafimvytxu .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #aafimvytxu .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #aafimvytxu .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #aafimvytxu .gt_row_group_first td { border-top-width: 2px; }
#  #aafimvytxu .gt_row_group_first th { border-top-width: 2px; }
#  #aafimvytxu .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #aafimvytxu .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #aafimvytxu .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #aafimvytxu .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #aafimvytxu .gt_left { text-align: left; }
#  #aafimvytxu .gt_center { text-align: center; }
#  #aafimvytxu .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #aafimvytxu .gt_font_normal { font-weight: normal; }
#  #aafimvytxu .gt_font_bold { font-weight: bold; }
#  #aafimvytxu .gt_font_italic { font-style: italic; }
#  #aafimvytxu .gt_super { font-size: 65%; }
#  #aafimvytxu .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #aafimvytxu .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Garden Party Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">A corpus of short stories from The Garden Party: and Other Stories by Katherine Mansfield. Texts downloaded from Project Gutenberg https://gutenberg.org/ and are in the public domain. The text files contain the short story without the title. https://github.com/ucdh/scraping-garden-party</td>
#   </tr>
#   <tr>
#     <td class="gt

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Build a Conc corpus from a CSV (or a compressed CSV) and prepare to report on it

# %% [markdown]
# The example assumes you've set the name and description of your corpus, as well as the `path_to_source_file` and `save_path` variables. The `path_to_source_file` can be a .csv file or a compressed .csv.gz file. This example assumes the CSV has a column called `text` containing the text to be analysed and another column called `source`, which will be retained as metadata.

# %%
#| eval: false
from conc.corpus import Corpus
from conc.conc import Conc

# %%
#| hide
name = 'Brown Corpus'
description = 'A Standard Corpus of Present-Day Edited American English, for use with Digital Computers. by W. N. Francis and H. Kucera (1964) Department of Linguistics, Brown University Providence, Rhode Island, USA Revised 1971, Revised and Amplified 1979 http://www.hit.uib.no/icame/brown/bcm.html. This version downloaded via NLTK https://www.nltk.org/nltk_data/.'
source_file = 'brown.csv.gz'
path_to_source_file = f'{source_path}{source_file}'

# %%
#| eval: false
corpus = Corpus(name=name, description=description).build_from_csv(source_path=path_to_source_file, save_path=save_path, text_column='text', metadata_columns=['source'])
corpus.summary()
conc = Conc(corpus=corpus) # prerequisite for running reports
# Out:
# <div id="anrhqclzsr" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #anrhqclzsr table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #anrhqclzsr thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #anrhqclzsr p { margin: 0; padding: 0; }
#  #anrhqclzsr .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #anrhqclzsr .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #anrhqclzsr .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #anrhqclzsr .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #anrhqclzsr .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #anrhqclzsr .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #anrhqclzsr .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #anrhqclzsr .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #anrhqclzsr .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #anrhqclzsr .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #anrhqclzsr .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #anrhqclzsr .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #anrhqclzsr .gt_spanner_row { border-bottom-style: hidden; }
#  #anrhqclzsr .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #anrhqclzsr .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #anrhqclzsr .gt_from_md> :first-child { margin-top: 0; }
#  #anrhqclzsr .gt_from_md> :last-child { margin-bottom: 0; }
#  #anrhqclzsr .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #anrhqclzsr .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #anrhqclzsr .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #anrhqclzsr .gt_row_group_first td { border-top-width: 2px; }
#  #anrhqclzsr .gt_row_group_first th { border-top-width: 2px; }
#  #anrhqclzsr .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #anrhqclzsr .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #anrhqclzsr .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #anrhqclzsr .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #anrhqclzsr .gt_left { text-align: left; }
#  #anrhqclzsr .gt_center { text-align: center; }
#  #anrhqclzsr .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #anrhqclzsr .gt_font_normal { font-weight: normal; }
#  #anrhqclzsr .gt_font_bold { font-weight: bold; }
#  #anrhqclzsr .gt_font_italic { font-style: italic; }
#  #anrhqclzsr .gt_super { font-size: 65%; }
#  #anrhqclzsr .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #anrhqclzsr .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Brown Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">A Standard Corpus of Present-Day Edited American English, for use with Digital Computers. by W. N. Francis and H. Kucera (1964) Department of Linguistics, Brown University Providence, Rhode Island, USA Revised 1971, Revised and Amplified 1979 http://www.hit.uib.no/icame/brown/bcm.html. This version downloaded via NLTK https://www.

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Load a Conc corpus and prepare to report on it

# %% [markdown]
# The example assumes you've built a corpus previously with Conc and you've set the `corpus_path` (i.e. the corpus path created when you built your corpus).

# %%
#| eval: false
from conc.corpus import Corpus
from conc.conc import Conc

# %%
#| hide
corpus_path = f'{save_path}garden-party.corpus'

# %%
#| eval: false
corpus = Corpus().load(corpus_path=corpus_path)
corpus.summary()
conc = Conc(corpus=corpus) # prerequisite for running reports
# Out:
# <div id="pfkrpuhrbk" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #pfkrpuhrbk table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #pfkrpuhrbk thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #pfkrpuhrbk p { margin: 0; padding: 0; }
#  #pfkrpuhrbk .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #pfkrpuhrbk .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #pfkrpuhrbk .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #pfkrpuhrbk .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #pfkrpuhrbk .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #pfkrpuhrbk .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #pfkrpuhrbk .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #pfkrpuhrbk .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #pfkrpuhrbk .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #pfkrpuhrbk .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #pfkrpuhrbk .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #pfkrpuhrbk .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #pfkrpuhrbk .gt_spanner_row { border-bottom-style: hidden; }
#  #pfkrpuhrbk .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #pfkrpuhrbk .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #pfkrpuhrbk .gt_from_md> :first-child { margin-top: 0; }
#  #pfkrpuhrbk .gt_from_md> :last-child { margin-bottom: 0; }
#  #pfkrpuhrbk .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #pfkrpuhrbk .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #pfkrpuhrbk .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #pfkrpuhrbk .gt_row_group_first td { border-top-width: 2px; }
#  #pfkrpuhrbk .gt_row_group_first th { border-top-width: 2px; }
#  #pfkrpuhrbk .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #pfkrpuhrbk .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #pfkrpuhrbk .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #pfkrpuhrbk .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #pfkrpuhrbk .gt_left { text-align: left; }
#  #pfkrpuhrbk .gt_center { text-align: center; }
#  #pfkrpuhrbk .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #pfkrpuhrbk .gt_font_normal { font-weight: normal; }
#  #pfkrpuhrbk .gt_font_bold { font-weight: bold; }
#  #pfkrpuhrbk .gt_font_italic { font-style: italic; }
#  #pfkrpuhrbk .gt_super { font-size: 65%; }
#  #pfkrpuhrbk .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #pfkrpuhrbk .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Garden Party Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">A corpus of short stories from The Garden Party: and Other Stories by Katherine Mansfield. Texts downloaded from Project Gutenberg https://gutenberg.org/ and are in the public domain. The text files contain the short story without the title. https://github.com/ucdh/scraping-garden-party</td>
#   </tr>
#   <tr>
#     <td class="gt

# %% [markdown]
# :::

# %% [markdown]
# ## Reports for corpus analysis

# %% [markdown]
# The example snippets below assume you've built or loaded a corpus and prepared it for reporting (see above).

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Frequency report

# %%
#| eval: false
conc.frequencies().display()
# Out:
# <div id="mcsllaxlwk" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #mcsllaxlwk table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #mcsllaxlwk thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #mcsllaxlwk p { margin: 0; padding: 0; }
#  #mcsllaxlwk .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #mcsllaxlwk .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #mcsllaxlwk .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #mcsllaxlwk .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #mcsllaxlwk .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mcsllaxlwk .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #mcsllaxlwk .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mcsllaxlwk .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #mcsllaxlwk .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #mcsllaxlwk .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #mcsllaxlwk .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #mcsllaxlwk .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #mcsllaxlwk .gt_spanner_row { border-bottom-style: hidden; }
#  #mcsllaxlwk .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #mcsllaxlwk .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #mcsllaxlwk .gt_from_md> :first-child { margin-top: 0; }
#  #mcsllaxlwk .gt_from_md> :last-child { margin-bottom: 0; }
#  #mcsllaxlwk .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #mcsllaxlwk .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #mcsllaxlwk .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #mcsllaxlwk .gt_row_group_first td { border-top-width: 2px; }
#  #mcsllaxlwk .gt_row_group_first th { border-top-width: 2px; }
#  #mcsllaxlwk .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #mcsllaxlwk .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #mcsllaxlwk .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #mcsllaxlwk .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #mcsllaxlwk .gt_left { text-align: left; }
#  #mcsllaxlwk .gt_center { text-align: center; }
#  #mcsllaxlwk .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #mcsllaxlwk .gt_font_normal { font-weight: normal; }
#  #mcsllaxlwk .gt_font_bold { font-weight: bold; }
#  #mcsllaxlwk .gt_font_italic { font-style: italic; }
#  #mcsllaxlwk .gt_super { font-size: 65%; }
#  #mcsllaxlwk .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #mcsllaxlwk .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Garden Party Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the</td>
#     <td class="gt_row gt_right">2,911</td>
#     <td class="gt_row gt_right">489.13</td>
#   </tr>
#   <tr>
#     <td class="gt_ro

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Ngram frequencies report

# %%
#| eval: false
conc.ngram_frequencies(ngram_length = 2).display()
# Out:
# <div id="fqwlaixgal" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #fqwlaixgal table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #fqwlaixgal thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #fqwlaixgal p { margin: 0; padding: 0; }
#  #fqwlaixgal .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #fqwlaixgal .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #fqwlaixgal .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #fqwlaixgal .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #fqwlaixgal .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #fqwlaixgal .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #fqwlaixgal .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #fqwlaixgal .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #fqwlaixgal .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #fqwlaixgal .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #fqwlaixgal .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #fqwlaixgal .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #fqwlaixgal .gt_spanner_row { border-bottom-style: hidden; }
#  #fqwlaixgal .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #fqwlaixgal .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #fqwlaixgal .gt_from_md> :first-child { margin-top: 0; }
#  #fqwlaixgal .gt_from_md> :last-child { margin-bottom: 0; }
#  #fqwlaixgal .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #fqwlaixgal .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #fqwlaixgal .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #fqwlaixgal .gt_row_group_first td { border-top-width: 2px; }
#  #fqwlaixgal .gt_row_group_first th { border-top-width: 2px; }
#  #fqwlaixgal .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #fqwlaixgal .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #fqwlaixgal .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #fqwlaixgal .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #fqwlaixgal .gt_left { text-align: left; }
#  #fqwlaixgal .gt_center { text-align: center; }
#  #fqwlaixgal .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #fqwlaixgal .gt_font_normal { font-weight: normal; }
#  #fqwlaixgal .gt_font_bold { font-weight: bold; }
#  #fqwlaixgal .gt_font_italic { font-style: italic; }
#  #fqwlaixgal .gt_super { font-size: 65%; }
#  #fqwlaixgal .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #fqwlaixgal .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngram Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Garden Party Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">it was</td>
#     <td class="gt_row gt_right">247</td>
#     <td class="gt_row gt_right">41.50</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_right">2</td>

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Keywords report

# %% [markdown]
# For a keywords report you will need another corpus to compare against. This example assumes you've already built that and have defined the `reference_corpus_path` variable. When you load the reference corpus, set it to `reference_corpus` or some other variable name to help you distinguish it from the corpus you are reporting on.

# %%
#| hide
reference_corpus_path = f'{save_path}brown.corpus'

# %%
#| eval: false
reference_corpus = Corpus().load(corpus_path=reference_corpus_path)
conc.set_reference_corpus(reference_corpus)
conc.keywords(min_document_frequency = 5, min_document_frequency_reference = 5).display()
# Out:
# <div id="hqrmhphuuo" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #hqrmhphuuo table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #hqrmhphuuo thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #hqrmhphuuo p { margin: 0; padding: 0; }
#  #hqrmhphuuo .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #hqrmhphuuo .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #hqrmhphuuo .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #hqrmhphuuo .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #hqrmhphuuo .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hqrmhphuuo .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hqrmhphuuo .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hqrmhphuuo .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #hqrmhphuuo .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #hqrmhphuuo .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #hqrmhphuuo .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #hqrmhphuuo .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #hqrmhphuuo .gt_spanner_row { border-bottom-style: hidden; }
#  #hqrmhphuuo .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #hqrmhphuuo .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #hqrmhphuuo .gt_from_md> :first-child { margin-top: 0; }
#  #hqrmhphuuo .gt_from_md> :last-child { margin-bottom: 0; }
#  #hqrmhphuuo .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #hqrmhphuuo .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #hqrmhphuuo .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #hqrmhphuuo .gt_row_group_first td { border-top-width: 2px; }
#  #hqrmhphuuo .gt_row_group_first th { border-top-width: 2px; }
#  #hqrmhphuuo .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #hqrmhphuuo .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hqrmhphuuo .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #hqrmhphuuo .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #hqrmhphuuo .gt_left { text-align: left; }
#  #hqrmhphuuo .gt_center { text-align: center; }
#  #hqrmhphuuo .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #hqrmhphuuo .gt_font_normal { font-weight: normal; }
#  #hqrmhphuuo .gt_font_bold { font-weight: bold; }
#  #hqrmhphuuo .gt_font_italic { font-style: italic; }
#  #hqrmhphuuo .gt_super { font-size: 65%; }
#  #hqrmhphuuo .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #hqrmhphuuo .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_title gt_font_normal">Keywords</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Target corpus: Garden Party Corpus, Reference corpus: Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency-Reference">Frequency Reference</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" s

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Collocates report

# %%
#| eval: false
conc.collocates('could').display()
# Out:
# <div id="ffyaefeufu" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ffyaefeufu table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ffyaefeufu thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ffyaefeufu p { margin: 0; padding: 0; }
#  #ffyaefeufu .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ffyaefeufu .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ffyaefeufu .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #ffyaefeufu .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #ffyaefeufu .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ffyaefeufu .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ffyaefeufu .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ffyaefeufu .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ffyaefeufu .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ffyaefeufu .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ffyaefeufu .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ffyaefeufu .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ffyaefeufu .gt_spanner_row { border-bottom-style: hidden; }
#  #ffyaefeufu .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ffyaefeufu .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ffyaefeufu .gt_from_md> :first-child { margin-top: 0; }
#  #ffyaefeufu .gt_from_md> :last-child { margin-bottom: 0; }
#  #ffyaefeufu .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ffyaefeufu .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ffyaefeufu .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ffyaefeufu .gt_row_group_first td { border-top-width: 2px; }
#  #ffyaefeufu .gt_row_group_first th { border-top-width: 2px; }
#  #ffyaefeufu .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #ffyaefeufu .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ffyaefeufu .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ffyaefeufu .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ffyaefeufu .gt_left { text-align: left; }
#  #ffyaefeufu .gt_center { text-align: center; }
#  #ffyaefeufu .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ffyaefeufu .gt_font_normal { font-weight: normal; }
#  #ffyaefeufu .gt_font_bold { font-weight: bold; }
#  #ffyaefeufu .gt_font_italic { font-style: italic; }
#  #ffyaefeufu .gt_super { font-size: 65%; }
#  #ffyaefeufu .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ffyaefeufu .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_title gt_font_normal">Collocates of &quot;could&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Garden Party Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Collocate-Frequency">Collocate Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Logdice">Logdice</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Log-Likelihood">Log Likelihood</th>

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Concordance

# %%
#| eval: false
conc.concordance('could', order = '1R2R3R', context_length = 10).display()
# Out:
# <div id="qvmkvmfymq" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #qvmkvmfymq table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #qvmkvmfymq thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #qvmkvmfymq p { margin: 0; padding: 0; }
#  #qvmkvmfymq .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #qvmkvmfymq .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #qvmkvmfymq .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #qvmkvmfymq .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #qvmkvmfymq .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #qvmkvmfymq .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #qvmkvmfymq .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #qvmkvmfymq .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #qvmkvmfymq .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #qvmkvmfymq .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #qvmkvmfymq .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #qvmkvmfymq .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #qvmkvmfymq .gt_spanner_row { border-bottom-style: hidden; }
#  #qvmkvmfymq .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #qvmkvmfymq .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #qvmkvmfymq .gt_from_md> :first-child { margin-top: 0; }
#  #qvmkvmfymq .gt_from_md> :last-child { margin-bottom: 0; }
#  #qvmkvmfymq .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #qvmkvmfymq .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #qvmkvmfymq .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #qvmkvmfymq .gt_row_group_first td { border-top-width: 2px; }
#  #qvmkvmfymq .gt_row_group_first th { border-top-width: 2px; }
#  #qvmkvmfymq .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #qvmkvmfymq .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #qvmkvmfymq .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #qvmkvmfymq .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #qvmkvmfymq .gt_left { text-align: left; }
#  #qvmkvmfymq .gt_center { text-align: center; }
#  #qvmkvmfymq .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #qvmkvmfymq .gt_font_normal { font-weight: normal; }
#  #qvmkvmfymq .gt_font_bold { font-weight: bold; }
#  #qvmkvmfymq .gt_font_italic { font-style: italic; }
#  #qvmkvmfymq .gt_super { font-size: 65%; }
#  #qvmkvmfymq .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #qvmkvmfymq .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Concordance for &quot;could&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Garden Party Corpus, Context tokens: 10, Order: 1R2R3R</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Doc-Id">Doc Id</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Left">Left</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="Node">Node</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Right">Right</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">4</td>
#     <td class="gt_row gt_right">herself and got as close to the sea as she</td>
#     <td class="gt_row gt_center">could</td>
#     <td class="gt_row gt_left">, and sung some

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Concordance plot

# %%
#| eval: false
conc.concordance_plot('he').display()
# Out:
# <script>
# var concplot_cc761e71782dc7dd2768e668c061d710 = {
# eof_token: 5223,
# page_size: 10,
# append_info: true,
# row_height: 60,
# start_first_row_at: 30,
# row_adjustment: 30,
# default_font_size: 12,
# subplot_height: 40,
# plot_height: 610,
# plot_x: 160,
# label_x_right: 150,
# docs: [{"doc_id":1,"positions":[11,31,82,90,107,132,138,157,205,257,267,350,355,360,494,504,508,554,561,587,857,866,888,895,941,1169,1179,1208,1578,1580,1744,1854,1974,2191,2201,2206,2256,2273,2285,2328,2455,2484,2583,2606,2657,2672,2692,2737,2741,2769,2814,2913,2917,2943,2947,2956,2982],"count":3174},{"doc_id":2,"positions":[409,472,479,666,839,851,1044,1385,1393,1495,1527,1553,1586,1594,1603,1620,1656,1664,1675,1706,1785,1801,1833,1839,1852,1882,1891,1910,1936,1950,2001,2103,2115,2147,2155,2189,2197,2211,2234,2289,2344,2368,2584,3153,3157,3166,3324,3365,4541,4720,4789,4814,5806,5813,5817,5851,5929,5941,5963,5971,5995,6924,7166,7290,7299,7374,7380,7395,7401,7411,7414,7440,7783,7816,7830,7836,7852,7856,7965,8013,8030,8124,8140,8153,8167,8173,8618,8632,9005,9012,9180,10857,11508,11517,11565,11703,11709,11726,11738,12025,12105,12341,12985,12996,13009,13205,13492,13501,13510,13525,13534,13549,13555,13565,13571,13604,13647,13656,13661,13774,14125,14254,14267,14570,14601,14606,14646,14654,14688,14705,14731,14748,14904,14922,14962,15125,15315,15329,15632,15638,16149,16176,16339,16372,16376,16615,16814,16852],"count":17017},{"doc_id":3,"positions":[40,242,253,280,1148,1173,1222,1275,1302],"count":1573},{"doc_id":4,"positions":[134,152,169,187,1437,1918,1927,1966,2002,2065,2068,2132,2153,2156,2168,2279,2335,2506,2727,2732,2742,2799,2889,3889,3921,4589,4593,4697,4763,5157,5234,5257,5260,5439,5460,5477,5493,5694,5707,5710,5748,5766,5786,5859,5881,5889,5944,6087,6101,6176,6243,6247,6346,6373,6457,6468,6522,6533,6548,6678,8171,8175,8513,8653],"count":9214},{"doc_id":5,"positions":[227,272,1315,1382,1451,1478,1782,1872,1906,2055,2312,2315,2338,2380,2403,2422,2454,2458,2561,2581,2727,2954,3178],"count":3202},{"doc_id":6,"positions":[22,95,104,122,126,153,204,263,406,437,461,532,559,645,665,671,685,700,1279,1300,1795,1808,1826,2000,2200,2204,2230,2244,2254,2301,2375,2383,2423,2427,2443,2447,2496,2502,2513,2626,2637,2745,2756],"count":3178},{"doc_id":7,"positions":[15,59,63,79,161,421,515,551,626,695,834,904,967,1058,1075,1121,1154,1182,1247,1256,1489,1587,1646,1659,1666,1877,1960,1993,2022,2029,2130,2442,2622,2711,2721,2785,2957,2969,3038,3044,3135,3533,3596,3604,3910,3916,4117,4172],"count":4997},{"doc_id":8,"positions":[410,619,675,681,1139,1254,1260,1266,1707,1741,1761,1763],"count":2407},{"doc_id":9,"positions":[2,10,19,38,55,100,137,146,162,171,177,192,197,277,285,308,318,331,360,433,437,454,530,593,650,654,682,723,784,802,807,817,846,974,1009,1144,1251,1312,1331,1482,1498,1543,1660,2032,2077,2141,2235,2247,2294,2306,2329,2436,2495,2531,2579,2619,2696,2806,2933,3050,3064,3239,3470,3523,3608,3711,3725,3729,3781,3784,3798,3802,3882,4002,4086,4099,4297,4304,4353,4356],"count":4393},{"doc_id":10,"positions":[511,551,692,711,825,829,846,862,1001,1433,2178,2730,3464,3520,3527,4051,4869,4878,4884,5296,5318,6733,6751,6782,6804,6812,6943,7034,7102],"count":7118},{"doc_id":11,"positions":[342,947,979,1007,1016,1074,1087,1100,1188,1789,1889,1895,2031,2411,2510,2538],"count":2779},{"doc_id":12,"positions":[1094,1112,1224,1242,1258,1264,1272,1285,1685,1792,1924,2256],"count":2792},{"doc_id":13,"positions":[168,191,211,353,386,420,544,608,707,740,838,855,859,890,894,908,947,969,982,1001,1030,1032,1047,1062,1095,1278,1334,1347,1427,1514,1525,1603,1609,1680,1686,1718,1767,1775,1836,2029,2058,2072,2115,2121,2184,2231,2259,2407,2420,2577,2594,2725,2741,2753,2756,2814,2834,2836,2956,2963,2975,2998,3088,3093,3113,3115,3146,3238,3284,3350,3366,3371,3395,3421,3446,3512,3533,3586,3722,3849,3916,3924,3953,3986,4001,4035,4080,4127,4165,4560,4588,4629,4632,4655,4660,4664,4669,4700,4709,4712,4738,4751,4796,4864,4881,4890,4894,4907,4989,5057,5089,5096,5113,5185,5203,5207,5212,5217,5253,5279,5375,5448,5462,5511,5523,5528,5534,5544,5566,5596,5603,5618,5627,5656,5661,5791,5796,5808,5836,5852,5858,5926,5933],"count":5963},{"doc_id":14,"positions":[308,583,596,721,876,883,908,947,951,1646,3477,3819,3945,3959],"count":3963},{"doc_id":15,"positions":[338,352,381,389,423, ...
# tokens: {"1":"X","4":"_","7":"Where","16":"stream","26":"alone","28":"tell","56":"kiddies","58":"morning","63":"fire","69":"muttered","90":"ask","95":"stopped","97":"my","103":"happy","106":"umbrella","111":"voice","121":"let","130":"poems","141":"shown","145":"ducky","155":"dashed","159":"prove","163":"here","168":"For","170":"confiding","177":"anyone","178":"not","181":"simply","187":"church","190":"interruption","194":"blot","197":"vaguely","200":"remembered","204":"beautiful","207":"cranky","233":"found","240":"’s","244":"nervously","247":";","249":"gleamed","258":"tone","264":"whom","271":"shy","274":"watching","279":"Josephine","280":"quiver","299":"foot","303":"brushed","309":"grave","318":"of","334":"hungry","337":"hair","347":"waited","348":"madam","349":"about","351":"afternoon","352":"puffed","373":"while","376":"addressed","399":"ruffled","402":"strode","404":"boots","414":"other","415":"faltered","416":"appeared","420":"pale","428":"died","431":"After","439":"has","450":"XII","456":"Quite","469":"speared","473":"getting","474":"absurd","481":"glazed","490":"bow","493":"terribly","499":"happened","500":"everybody","501":"Every","514":"wiped","519":"suicide","520":"took","524":"almighty","528":"spade","535":"fly","537":"perhaps","539":"Of","544":"your","545":"tiny","554":"day","560":"Just","561":"listened","567":"able","571":"he","580":"walk","582":"floated","588":"He","592":"out","593":"cheated","598":"clasped","605":"him","611":"Avanti","612":"sorry","614":"yesterday","627":"bit","633":"does","639":"fast","643":"legs","651":"French","675":"managed","676":"much","677":"noise?—that","683":"oak","691":"this","699":"get","702":"longer","703":"fall","708":"watch","715":"garden","721":"there","726":"spending","733":"do","734":"more","735":"dreamed","736":"passed","739":"myself","740":"convinced","748":"up","756":"rang","765":"understand","772":"and","776":"spoiled","798":"brought","800":"scurried","807":"hobbies","809":"children","817":"Reggie","820":"promised","827":"lilies","830":"thing","834":"flowers","838":"old","857":"dreadful","859":"haggard","865":"stayed","873":"earth","874":",","879":"it?—confirmed","882":"Harold","883":"then","889":"own","891":"chucked","892":"his","913":"completely","916":"shook","918":"course","919":"every","928":"stolen","935":"costs","940":"parasol","943":"White","945":"Splendid","965":"charming","968":"attractive","972":"until","1002":"in","1040":"man","1045":"cold","1048":"called","1054":"Could","1055":"reached","1056":"disappointment","1060":"chance","1063":"Reginald","1068":"shout","1071":"held","1080":"comfort","1083":"fond","1086":"faint","1100":"into","1103":"suggested","1119":"’d","1120":"special","1121":"Why","1141":"Stanley","1147":"is","1149":"Hallo","1154":"wanted","1156":"licence","1159":"escape","1171":"green","1173":"satisfactory","1182":"takes","1196":"die","1200":"things","1205":"speak","1209":"bring","1213":"followed","1218":"furious","1229":"Then","1233":"yet","1240":"frills","1246":"disappeared","1248":"love","1249":"spite","1255":"bear","1256":"or","1264":"altogether","1271":"to","1276":"facing","1283":"fact","1285":"hold","1299":"reflected","1300":"who","1305":"So","1306":"agree","1307":"being","1312":"Pinner","1323":"along","1326":"change","1330":"left","1332":"tall","1348":"Oh","1356":"whether","1363":"her","1375":"Perhaps","1377":"thoroughly","1382":"scarf","1387":"shot","1389":"rudely","1391":"mysteriously","1397":"impatient","1413":"journeys","1415":"melon","1418":"Mrs.","1423":"gone","1431":"As","1444":"tucked","1449":"passionately","1451":"that","1456":"follows","1466":"steward","1487":"Constantia","1490":"again

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### You can still output individual texts (and access the text and tokens programmatically)! Here is how ...

# %% [markdown]
# The texts are accessible via the Corpus object. If you display a text (as below) it will show any available metadata. Add `show_metadata=False` to just show the text. If you leave off the `max_tokens` parameter, it will display the entire text.

# %%
#| eval: false
corpus.text(2).display(max_tokens = 300)
# Out:
# 	<style>
# 	.conc-text-wrapper { background: #fff; color: #000; border: 1px solid #000;border-radius: 0.5em;width: max-content;padding: 0.3em; min-width: 400px;}
# 	.conc-text {margin:0.3em; white-space: pre-wrap; font-family: Georgia, Cambria, "Times New Roman", Times, serif;font-size: 1.3em; width: max-content;}
#   </style>
# 	<div class="conc-text-wrapper"><div id="cjqgmnfzpg" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #cjqgmnfzpg table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #cjqgmnfzpg thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #cjqgmnfzpg p { margin: 0; padding: 0; }
#  #cjqgmnfzpg .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #cjqgmnfzpg .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #cjqgmnfzpg .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #cjqgmnfzpg .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #cjqgmnfzpg .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #cjqgmnfzpg .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #cjqgmnfzpg .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #cjqgmnfzpg .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #cjqgmnfzpg .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #cjqgmnfzpg .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #cjqgmnfzpg .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #cjqgmnfzpg .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #cjqgmnfzpg .gt_spanner_row { border-bottom-style: hidden; }
#  #cjqgmnfzpg .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #cjqgmnfzpg .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #cjqgmnfzpg .gt_from_md> :first-child { margin-top: 0; }
#  #cjqgmnfzpg .gt_from_md> :last-child { margin-bottom: 0; }
#  #cjqgmnfzpg .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #cjqgmnfzpg .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #cjqgmnfzpg .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #cjqgmnfzpg .gt_row_group_first td { border-top-width: 2px; }
#  #cjqgmnfzpg .gt_row_group_first th { border-top-width: 2px; }
#  #cjqgmnfzpg .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #cjqgmnfzpg .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #cjqgmnfzpg .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #cjqgmnfzpg .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #cjqgmnfzpg .gt_left { text-align: left; }
#  #cjqgmnfzpg .gt_center { text-align: center; }
#  #cjqgmnfzpg .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #cjqgmnfzpg .gt_font_normal { font-weight: normal; }
#  #cjqgmnfzpg .gt_font_bold { font-weight: bold; }
#  #cjqgmnfzpg .gt_font_italic { font-style: italic; }
#  #cjqgmnfzpg .gt_super { font-size: 65%; }
#  #cjqgmnfzpg .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #cjqgmnfzpg .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Metadata</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">document_id</td>
#     <td class="gt_row gt_left">2</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">file</td>
#     <td class="gt_row g

# %% [markdown]
# Texts are also accessible as strings if you want to work with them like that ...

# %%
#| eval: false
text = corpus.text(1).as_string(max_tokens = 50)
print(text)
# Out:
# That evening for the first time in his life, as he pressed through the
# swing door and descended the three broad steps to the pavement, old Mr.
# Neave felt he was too old for the spring. Spring—warm, eager,
# restless—

# %% [markdown]
# or as tokens (this example loops through all texts in the corpus and displays the first 10 tokens) ...

# %%
#| eval: false
for i in range(1, corpus.document_count + 1):
    tokens = corpus.text(i).as_tokens() # this is all the tokens
    print(tokens[:10]) # slicing to first 10 tokens
# Out:
# ['That', 'evening', 'for', 'the', 'first', 'time', 'in', 'his', 'life', ',']
# ['I', '\r\n\r\n', 'Very', 'early', 'morning', '.', 'The', 'sun', 'was', 'not']
# ['A', 'stout', 'man', 'with', 'a', 'pink', 'face', 'wears', 'dingy', 'white']
# ['I', '\r\n\r\n', 'The', 'week', 'after', 'was', 'one', 'of', 'the', 'busiest']
# ['Exactly', 'when', 'the', 'ball', 'began', 'Leila', 'would', 'have', 'found', 'it']
# ['When', 'the', 'literary', 'gentleman', ',', 'whose', 'flat', 'old', 'Ma', 'Parker']
# ['On', 'his', 'way', 'to', 'the', 'station', 'William', 'remembered', 'with', 'a']
# ['Although', 'it', 'was', 'so', 'brilliantly', 'fine', '—', 'the', 'blue', 'sky']
# ['Of', 'course', 'he', 'knew', '—', 'no', 'man', 'better', '—', 'that']
# ['And', 'after', 'all', 'the', 'weather', 'was', 'ideal', '.', 'They', 'could']
# ['_', 'Eleven', 'o’clock', '.', 'A', 'knock', 'at', 'the', 'door', '.']
# ['With', 'despair', '—', 'cold', ',', 'sharp', 'despair', '—', 'buried', 'deep']
# ['It', 'seemed', 'to', 'the', 'little', 'crowd', 'on', 'the', 'wharf', 'that']
# ['The', 'Picton', 'boat', 'was', 'due', 'to', 'leave', 'at', 'half', '-']
# ['In', 'her', 'blue', 'dress', ',', 'with', 'her', 'cheeks', 'lightly', 'flushed']

# %% [markdown]
# :::

# %% [markdown]
# ## Working with Conc results

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Accessing and working with Conc results

# %% [markdown]
# In the examples above we run reports and use `.display()` to output a report. You can access report data directly as a Polars dataframe using `.to_frame()`. This means you can work with the data in Polars to further filter the results or extend analysis.

# %%
#| eval: false
# same specific tokens to restrict the results below to
pronouns = ['i', 'you', 'he', 'she', 'it', 'we', 'they', 'me', 'him', 'her', 'us', 'them', 'mine', 'yours', 
            'his', 'hers', 'its', 'ours', 'yours', 'theirs']

# retrieve keyword report for these pronouns, which has normalized frequencies for each corpus
# the next line returns the result as a Polars dataframe using the `to_frame` method
df = conc.keywords(restrict_tokens = pronouns).to_frame()

# %%
#| eval: false
# now go for it - work with the Polars dataframe
# e.g. show a table of results showing specific columns, display top 10 results ordered by normalized frequency descending
df.select(['token', 'normalized_frequency', 'normalized_frequency_reference']).sort('normalized_frequency', descending=True).head(10)
# Out:
# ┌───────┬──────────────────────┬────────────────────────────────┐
# │ token ┆ normalized_frequency ┆ normalized_frequency_reference │
# ╞═══════╪══════════════════════╪════════════════════════════════╡
# │ she   ┆ 196.760426           ┆ 21.01732                       │
# │ it    ┆ 171.556272           ┆ 71.326254                      │
# │ her   ┆ 157.441946           ┆ 29.454856                      │
# │ i     ┆ 120.81191            ┆ 44.585285                      │
# │ he    ┆ 120.643882           ┆ 69.091889                      │
# │ you   ┆ 107.873778           ┆ 33.311432                      │
# │ his   ┆ 73.932184            ┆ 66.551446                      │
# │ they  ┆ 66.875021            ┆ 28.995739                      │
# │ them  ┆ 35.285815            ┆ 18.232015                      │
# │ him   ┆ 32.093289            ┆ 26.720564                      │
# └───────┴──────────────────────┴────────────────────────────────┘

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Working with Conc results using Pandas

# %% [markdown]
# You are not restricted to Conc for your analysis. Conc report data can be exported to other formats. For example, although Conc uses [Polars](https://pola.rs/) internally for its efficiency, you can convert report results into a [Pandas](https://pandas.pydata.org/) dataframe, which is flexible and interoperable with many Python libraries for data analysis. Here is an example ...

# %%
#| eval: false
import pandas as pd # Conc does not install Pandas - so if you haven't already, install it with "pip install pandas"

# %%
#| eval: false
# same specific tokens to restrict the results below to
pronouns = ['i', 'you', 'he', 'she', 'it', 'we', 'they', 'me', 'him', 'her', 'us', 'them', 'mine', 'yours', 
            'his', 'hers', 'its', 'ours', 'yours', 'theirs']

# retrieve keyword report for these pronouns, which has normalized frequencies for each corpus
# the next line returns the result as a Polars dataframe, which is then converted to a Pandas dataframe
df = conc.keywords(restrict_tokens = pronouns).to_frame().to_pandas()

# %%
#| eval: false
# now go for it - do the pandas stuff you are familiar with ...
# e.g. show a table of results showing specific columns, display top 10 results ordered by normalized frequency descending
# note you could do this in Polars (see above), but this is assuming you are more familiar with Pandas
df.sort_values(by='normalized_frequency', ascending=False)[['token', 'normalized_frequency', 'normalized_frequency_reference']].head(10)
# Out:
#    token  normalized_frequency  normalized_frequency_reference
# 0    she            196.760426                       21.017320
# 7     it            171.556272                       71.326254
# 2    her            157.441946                       29.454856
# 6      i            120.811910                       44.585285
# 12    he            120.643882                       69.091889
# 5    you            107.873778                       33.311432
# 15   his             73.932184                       66.551446
# 9   they             66.875021                       28.995739
# 10  them             35.285815                       18.232015
# 14   him             32.093289                       26.720564

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Want to work with Conc results using other software/libraries? Exporting Conc results to CSV, JSON and other formats

# %% [markdown]
# If you want to work with Conc results in other libraries or software, you can write the results to an interoperable data format. Conc results can be accessed as Polars dataframes, which can be exported to CSV or JSON formats. See the [Polars input/output documentation](https://docs.pola.rs/api/python/dev/reference/io.html) for other formats supported, including Parquet, newline-delimited JSON, Excel and more.

# %%
#| eval: false
# same specific tokens to restrict the results below to
pronouns = ['i', 'you', 'he', 'she', 'it', 'we', 'they', 'me', 'him', 'her', 'us', 'them', 'mine', 'yours', 
            'his', 'hers', 'its', 'ours', 'yours', 'theirs']

# retrieve keyword report for these pronouns, which has normalized frequencies for each corpus
# the next line returns the result as a Polars dataframe using the `to_frame` method
df = conc.keywords(restrict_tokens = pronouns).to_frame()

# %% [markdown]
# The result in df is currently a Polars dataframe, write to CSV ...

# %%
#| eval: false
df.write_csv(f'pronoun-results.csv')

# %%
#| hide
if os.path.exists(f'pronoun-results.csv'):
	os.remove(f'pronoun-results.csv')  # cleanup

# %% [markdown]
# Here is how to write the results to a JSON file ...

# %%
#| eval: false
df.write_json(f'pronoun-results.json')

# %%
#| hide
if os.path.exists(f'pronoun-results.json'):
	os.remove(f'pronoun-results.json')  # cleanup

# %% [markdown]
# :::

# %% [markdown]
# ## Working with Conc corpus data

# %% [markdown]
# If Conc does not do something you want, you can work with a Conc corpus data directly.

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Working with a loaded Corpus

# %% [markdown]
# When you build or load a corpus the token, vocab and other data is accessible via the Corpus object. These could be very large and are not loaded into memory, but they can be queried via [Polars Lazy API](https://docs.pola.rs/user-guide/lazy/). Read about the [Anatomy of a Conc Corpus](https://geoffford.nz/conc/explanations/anatomy.html) for more information. Here is an example ...

# %%
#| eval: false
import polars as pl

# %%
#| eval: false
# e.g. filter vocab by tokens ending in 'ing'
corpus.vocab.filter(pl.col('token').str.ends_with('ing')).head(5).collect(engine='streaming')
# Out:
# ┌──────┬───────────────────┬──────────┬───────────┬─────────────────┬────────────────┬──────────┬──────────┐
# │ rank ┆ tokens_sort_order ┆ token_id ┆ token     ┆ frequency_lower ┆ frequency_orth ┆ is_punct ┆ is_space │
# ╞══════╪═══════════════════╪══════════╪═══════════╪═════════════════╪════════════════╪══════════╪══════════╡
# │ 99   ┆ 4979              ┆ 5920     ┆ something ┆ 100             ┆ 96             ┆ false    ┆ false    │
# │ 171  ┆ 2275              ┆ 4862     ┆ going     ┆ 59              ┆ 59             ┆ false    ┆ false    │
# │ 205  ┆ 3206              ┆ 5170     ┆ looking   ┆ 48              ┆ 46             ┆ false    ┆ false    │
# │ 214  ┆ 5509              ┆ 830      ┆ thing     ┆ 44              ┆ 44             ┆ false    ┆ false    │
# │ 236  ┆ 3650              ┆ 4679     ┆ nothing   ┆ 51              ┆ 41             ┆ false    ┆ false    │
# └──────┴───────────────────┴──────────┴───────────┴─────────────────┴────────────────┴──────────┴──────────┘

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Working with Conc corpus data files directly

# %% [markdown]
# There are a number of different data files that make up a Conc corpus. These can be queried directly if required. Read about the [Anatomy of a Conc Corpus](https://geoffford.nz/conc/explanations/anatomy.html) for an explanation of the format and data. Here is an example ...

# %%
#| eval: false
import polars as pl

# %%
#| eval: false
# e.g. lazy query to get tokens from vocab ending in 'ing'
display(pl.scan_parquet(f'{save_path}garden-party.corpus/vocab.parquet').filter(pl.col('token').str.ends_with('ing')).head(5).collect(engine='streaming'))
# Out:
# ┌──────┬───────────────────┬──────────┬───────────┬─────────────────┬────────────────┬──────────┬──────────┐
# │ rank ┆ tokens_sort_order ┆ token_id ┆ token     ┆ frequency_lower ┆ frequency_orth ┆ is_punct ┆ is_space │
# ╞══════╪═══════════════════╪══════════╪═══════════╪═════════════════╪════════════════╪══════════╪══════════╡
# │ 99   ┆ 4979              ┆ 5920     ┆ something ┆ 100             ┆ 96             ┆ false    ┆ false    │
# │ 171  ┆ 2275              ┆ 4862     ┆ going     ┆ 59              ┆ 59             ┆ false    ┆ false    │
# │ 205  ┆ 3206              ┆ 5170     ┆ looking   ┆ 48              ┆ 46             ┆ false    ┆ false    │
# │ 214  ┆ 5509              ┆ 830      ┆ thing     ┆ 44              ┆ 44             ┆ false    ┆ false    │
# │ 236  ┆ 3650              ┆ 4679     ┆ nothing   ┆ 51              ┆ 41             ┆ false    ┆ false    │
# └──────┴───────────────────┴──────────┴───────────┴─────────────────┴────────────────┴──────────┴──────────┘

# %% [markdown]
# :::
