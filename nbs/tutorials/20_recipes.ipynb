# %%
#| hide
import os

# %%
#| hide
source_path = f'{os.environ.get("HOME")}/data/'  
save_path = f'{os.environ.get("HOME")}/data/conc-test-corpora/'

# %% [markdown]
# # Quick Conc Recipes
#
# > Below are code snippets for common tasks in Conc.
# - toc: false
# - page-layout: full

# %% [markdown]
# The [Get started with Conc](https://geoffford.nz/conc/tutorials/start.html) tutorial (in progress) is a detailed step through Conc functionality. This page provides simple code recipes for common Conc tasks. See the [Conc API Reference](https://geoffford.nz/conc/api) for information on available methods, functions and parameters.

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Minimal import to use Conc functionality

# %%
#| eval: false
from conc.corpus import Corpus # for building/saving, loading, and working with a corpus
from conc.conc import Conc # for running reporting on your corpus

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Build a Conc corpus from text files (or a compressed archive of text files)

# %%
#| eval: false
name = 'Garden Party Corpus'
description = 'A corpus of short stories from The Garden Party: and Other Stories by Katherine Mansfield. Texts downloaded from Project Gutenberg https://gutenberg.org/ and are in the public domain. The text files contain the short story without the title. https://github.com/ucdh/scraping-garden-party'
source_file = 'garden-party-corpus.zip'

corpus = Corpus(name=name, description=description).build_from_files(source_path = f'{source_path}{source_file}', save_path = save_path)
corpus.summary()
# Out:
# <div id="rvzebrwtih" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #rvzebrwtih table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #rvzebrwtih thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #rvzebrwtih p { margin: 0; padding: 0; }
#  #rvzebrwtih .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #rvzebrwtih .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #rvzebrwtih .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #rvzebrwtih .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #rvzebrwtih .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rvzebrwtih .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rvzebrwtih .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rvzebrwtih .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #rvzebrwtih .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #rvzebrwtih .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #rvzebrwtih .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #rvzebrwtih .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #rvzebrwtih .gt_spanner_row { border-bottom-style: hidden; }
#  #rvzebrwtih .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #rvzebrwtih .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #rvzebrwtih .gt_from_md> :first-child { margin-top: 0; }
#  #rvzebrwtih .gt_from_md> :last-child { margin-bottom: 0; }
#  #rvzebrwtih .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #rvzebrwtih .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #rvzebrwtih .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #rvzebrwtih .gt_row_group_first td { border-top-width: 2px; }
#  #rvzebrwtih .gt_row_group_first th { border-top-width: 2px; }
#  #rvzebrwtih .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #rvzebrwtih .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rvzebrwtih .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rvzebrwtih .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #rvzebrwtih .gt_left { text-align: left; }
#  #rvzebrwtih .gt_center { text-align: center; }
#  #rvzebrwtih .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #rvzebrwtih .gt_font_normal { font-weight: normal; }
#  #rvzebrwtih .gt_font_bold { font-weight: bold; }
#  #rvzebrwtih .gt_font_italic { font-style: italic; }
#  #rvzebrwtih .gt_super { font-size: 65%; }
#  #rvzebrwtih .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #rvzebrwtih .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Garden Party Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">A corpus of short stories from The Garden Party: and Other Stories by Katherine Mansfield. Texts downloaded from Project Gutenberg https://gutenberg.org/ and are in the public domain. The text files contain the short story without the title. https://github.com/ucdh/scraping-garden-party</td>
#   </tr>
#   <tr>
#     <td class="gt

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Load a Conc corpus

# %%
#| eval: false
corpus = Corpus().load(corpus_path=f'{save_path}garden-party.corpus')

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Prepare to report on your corpus

# %%
#| eval: false
conc = Conc(corpus=corpus)

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Frequency report

# %%
#| eval: false
conc.frequencies().display()
# Out:
# <div id="vafnddilcd" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #vafnddilcd table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #vafnddilcd thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #vafnddilcd p { margin: 0; padding: 0; }
#  #vafnddilcd .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #vafnddilcd .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #vafnddilcd .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #vafnddilcd .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #vafnddilcd .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #vafnddilcd .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #vafnddilcd .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #vafnddilcd .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #vafnddilcd .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #vafnddilcd .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #vafnddilcd .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #vafnddilcd .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #vafnddilcd .gt_spanner_row { border-bottom-style: hidden; }
#  #vafnddilcd .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #vafnddilcd .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #vafnddilcd .gt_from_md> :first-child { margin-top: 0; }
#  #vafnddilcd .gt_from_md> :last-child { margin-bottom: 0; }
#  #vafnddilcd .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #vafnddilcd .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #vafnddilcd .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #vafnddilcd .gt_row_group_first td { border-top-width: 2px; }
#  #vafnddilcd .gt_row_group_first th { border-top-width: 2px; }
#  #vafnddilcd .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #vafnddilcd .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #vafnddilcd .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #vafnddilcd .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #vafnddilcd .gt_left { text-align: left; }
#  #vafnddilcd .gt_center { text-align: center; }
#  #vafnddilcd .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #vafnddilcd .gt_font_normal { font-weight: normal; }
#  #vafnddilcd .gt_font_bold { font-weight: bold; }
#  #vafnddilcd .gt_font_italic { font-style: italic; }
#  #vafnddilcd .gt_super { font-size: 65%; }
#  #vafnddilcd .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #vafnddilcd .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Garden Party Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the</td>
#     <td class="gt_row gt_right">2,911</td>
#     <td class="gt_row gt_right">459.79</td>
#   </tr>
#   <tr>
#     <td class="gt_ro

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Ngram frequencies report

# %%
#| eval: false
conc.ngram_frequencies(ngram_length = 2).display()
# Out:
# <div id="yhrdpgzuif" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #yhrdpgzuif table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #yhrdpgzuif thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #yhrdpgzuif p { margin: 0; padding: 0; }
#  #yhrdpgzuif .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #yhrdpgzuif .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #yhrdpgzuif .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #yhrdpgzuif .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #yhrdpgzuif .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #yhrdpgzuif .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #yhrdpgzuif .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #yhrdpgzuif .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #yhrdpgzuif .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #yhrdpgzuif .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #yhrdpgzuif .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #yhrdpgzuif .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #yhrdpgzuif .gt_spanner_row { border-bottom-style: hidden; }
#  #yhrdpgzuif .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #yhrdpgzuif .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #yhrdpgzuif .gt_from_md> :first-child { margin-top: 0; }
#  #yhrdpgzuif .gt_from_md> :last-child { margin-bottom: 0; }
#  #yhrdpgzuif .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #yhrdpgzuif .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #yhrdpgzuif .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #yhrdpgzuif .gt_row_group_first td { border-top-width: 2px; }
#  #yhrdpgzuif .gt_row_group_first th { border-top-width: 2px; }
#  #yhrdpgzuif .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #yhrdpgzuif .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #yhrdpgzuif .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #yhrdpgzuif .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #yhrdpgzuif .gt_left { text-align: left; }
#  #yhrdpgzuif .gt_center { text-align: center; }
#  #yhrdpgzuif .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #yhrdpgzuif .gt_font_normal { font-weight: normal; }
#  #yhrdpgzuif .gt_font_bold { font-weight: bold; }
#  #yhrdpgzuif .gt_font_italic { font-style: italic; }
#  #yhrdpgzuif .gt_super { font-size: 65%; }
#  #yhrdpgzuif .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #yhrdpgzuif .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngram Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Garden Party Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">” said</td>
#     <td class="gt_row gt_right">328</td>
#     <td class="gt_row gt_right">51.81</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_right">2</td>

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Keywords report

# %%
#| eval: false
reference_corpus = Corpus().load(f'{save_path}brown.corpus')
conc.set_reference_corpus(reference_corpus)
conc.keywords(min_document_frequency = 5, min_document_frequency_reference = 5).display()
# Out:
# <div id="jcotmjqakh" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #jcotmjqakh table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #jcotmjqakh thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #jcotmjqakh p { margin: 0; padding: 0; }
#  #jcotmjqakh .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #jcotmjqakh .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #jcotmjqakh .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #jcotmjqakh .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #jcotmjqakh .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jcotmjqakh .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jcotmjqakh .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jcotmjqakh .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #jcotmjqakh .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #jcotmjqakh .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #jcotmjqakh .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #jcotmjqakh .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #jcotmjqakh .gt_spanner_row { border-bottom-style: hidden; }
#  #jcotmjqakh .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #jcotmjqakh .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #jcotmjqakh .gt_from_md> :first-child { margin-top: 0; }
#  #jcotmjqakh .gt_from_md> :last-child { margin-bottom: 0; }
#  #jcotmjqakh .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #jcotmjqakh .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #jcotmjqakh .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #jcotmjqakh .gt_row_group_first td { border-top-width: 2px; }
#  #jcotmjqakh .gt_row_group_first th { border-top-width: 2px; }
#  #jcotmjqakh .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #jcotmjqakh .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jcotmjqakh .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #jcotmjqakh .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #jcotmjqakh .gt_left { text-align: left; }
#  #jcotmjqakh .gt_center { text-align: center; }
#  #jcotmjqakh .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #jcotmjqakh .gt_font_normal { font-weight: normal; }
#  #jcotmjqakh .gt_font_bold { font-weight: bold; }
#  #jcotmjqakh .gt_font_italic { font-style: italic; }
#  #jcotmjqakh .gt_super { font-size: 65%; }
#  #jcotmjqakh .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #jcotmjqakh .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_title gt_font_normal">Keywords</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Target corpus: Garden Party Corpus, Reference corpus: Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency Reference">Frequency Reference</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" s

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Collocates report

# %%
#| eval: false
conc.collocates('could').display()
# Out:
# <div id="biskcakaxs" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #biskcakaxs table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #biskcakaxs thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #biskcakaxs p { margin: 0; padding: 0; }
#  #biskcakaxs .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #biskcakaxs .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #biskcakaxs .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #biskcakaxs .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #biskcakaxs .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #biskcakaxs .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #biskcakaxs .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #biskcakaxs .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #biskcakaxs .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #biskcakaxs .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #biskcakaxs .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #biskcakaxs .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #biskcakaxs .gt_spanner_row { border-bottom-style: hidden; }
#  #biskcakaxs .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #biskcakaxs .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #biskcakaxs .gt_from_md> :first-child { margin-top: 0; }
#  #biskcakaxs .gt_from_md> :last-child { margin-bottom: 0; }
#  #biskcakaxs .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #biskcakaxs .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #biskcakaxs .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #biskcakaxs .gt_row_group_first td { border-top-width: 2px; }
#  #biskcakaxs .gt_row_group_first th { border-top-width: 2px; }
#  #biskcakaxs .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #biskcakaxs .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #biskcakaxs .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #biskcakaxs .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #biskcakaxs .gt_left { text-align: left; }
#  #biskcakaxs .gt_center { text-align: center; }
#  #biskcakaxs .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #biskcakaxs .gt_font_normal { font-weight: normal; }
#  #biskcakaxs .gt_font_bold { font-weight: bold; }
#  #biskcakaxs .gt_font_italic { font-style: italic; }
#  #biskcakaxs .gt_super { font-size: 65%; }
#  #biskcakaxs .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #biskcakaxs .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_title gt_font_normal">Collocates of &quot;could&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Garden Party Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Collocate Frequency">Collocate Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Logdice">Logdice</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Log Likelihood">Log Likelihood</th>

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Concordance

# %%
#| eval: false
conc.concordance('could', order = '1R2R3R', context_length = 10).display()
# Out:
# <div id="wyooqnkaus" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #wyooqnkaus table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #wyooqnkaus thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #wyooqnkaus p { margin: 0; padding: 0; }
#  #wyooqnkaus .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #wyooqnkaus .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #wyooqnkaus .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #wyooqnkaus .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #wyooqnkaus .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wyooqnkaus .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #wyooqnkaus .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wyooqnkaus .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #wyooqnkaus .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #wyooqnkaus .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #wyooqnkaus .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #wyooqnkaus .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #wyooqnkaus .gt_spanner_row { border-bottom-style: hidden; }
#  #wyooqnkaus .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #wyooqnkaus .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #wyooqnkaus .gt_from_md> :first-child { margin-top: 0; }
#  #wyooqnkaus .gt_from_md> :last-child { margin-bottom: 0; }
#  #wyooqnkaus .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #wyooqnkaus .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #wyooqnkaus .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #wyooqnkaus .gt_row_group_first td { border-top-width: 2px; }
#  #wyooqnkaus .gt_row_group_first th { border-top-width: 2px; }
#  #wyooqnkaus .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #wyooqnkaus .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #wyooqnkaus .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #wyooqnkaus .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #wyooqnkaus .gt_left { text-align: left; }
#  #wyooqnkaus .gt_center { text-align: center; }
#  #wyooqnkaus .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #wyooqnkaus .gt_font_normal { font-weight: normal; }
#  #wyooqnkaus .gt_font_bold { font-weight: bold; }
#  #wyooqnkaus .gt_font_italic { font-style: italic; }
#  #wyooqnkaus .gt_super { font-size: 65%; }
#  #wyooqnkaus .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #wyooqnkaus .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Concordance for &quot;could&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Garden Party Corpus, Context tokens: 10, Order: 1R2R3R</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Document Id">Document Id</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Left">Left</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Node">Node</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Right">Right</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">4</td>
#     <td class="gt_row gt_right">herself and got as close to the sea as she</td>
#     <td class="gt_row gt_left">could</td>
#     <td class="gt_row gt_left">, and sun

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Concordance plot

# %%
#| eval: false
conc.concordance_plot('could')
# Out:
# <script>
# var eof_token = 5223;
# var page_size = 10;
# var append_info = true;
# var row_height = 60;
# var start_first_row_at = 30;
# var row_adjustment = 30;
# var default_font_size = 12;
# var subplot_height = 40;
# var plot_height = 610;
# var plot_x = 160;
# var label_x_right = 150;
# var docs = [{"doc_id":1,"positions":[83,91,251,603,622,804,819,858,902,1129,2237],"count":3174},{"doc_id":2,"positions":[40,1657,1932,3106,3482,3721,3847,4319,5139,5148,5565,5604,5913,5919,5956,7396,7402,7520,7625,7674,7951,9411,9417,9473,10023,10274,10858,11276,12220,13303,14236,14467,15316,16196,16242,16355,16360,16446],"count":17017},{"doc_id":3,"positions":[450],"count":1573},{"doc_id":4,"positions":[645,683,1133,1195,1239,1454,1516,1890,2381,2679,2775,2827,2992,3004,3013,3389,3854,3875,4375,4885,5494,5795,5970,6743,6796,7288,7304,7493,7951,8202,8547,8639,8841],"count":9214},{"doc_id":5,"positions":[316,592,981,2792,3105],"count":3202},{"doc_id":6,"positions":[127,701,792,1043,2186,2311,2376,2514,2541,2757,2874,2968,2977,2984,3028,3047,3063,3106,3139],"count":3178},{"doc_id":7,"positions":[494,1446,1953,2131,3567,4014,4265,4333,4663,4763,4912],"count":4997},{"doc_id":8,"positions":[251,1491],"count":2407},{"doc_id":9,"positions":[188,286,438,526,583,594,818,992,1187,2593,2963,3145,3245,3388,3712,3780],"count":4393},{"doc_id":10,"positions":[9,97,223,337,412,1079,1384,1807,2786,3087,4433,4506,4634,5836,5842,6515,6873,7095],"count":7118},{"doc_id":11,"positions":[402,518,578,584,1189,1198,1552,1700,2258,2285,2362],"count":2779},{"doc_id":12,"positions":[499,985,1058,1069,1209,1265,1869,1947,1972,2332],"count":2792},{"doc_id":13,"positions":[55,1274,1837,2122,2212,2837,2957,3015,3044,3065,3935,4659,4739,4863,5208,5213,5376,5859],"count":5963},{"doc_id":14,"positions":[1620,2413,2799,2952,3100,3168,3197],"count":3963},{"doc_id":15,"positions":[1713,1791,2065,2312,2412,2693,2697],"count":2879}];
# var tokens = {"4":"_","7":"Where","26":"alone","28":"tell","87":"landing","90":"ask","98":"star","103":"happy","111":"voice","123":"Meg","155":"dashed","159":"prove","178":"not","181":"simply","240":"’s","247":";","251":"pay","276":"letter","279":"Josephine","292":"prevent","294":"cut","318":"of","349":"about","437":"told","438":"immense","443":"safely","460":"possible","480":"guess","485":"Grandma","544":"your","561":"listened","571":"he","588":"He","592":"out","596":"world","605":"him","645":"strangers","676":"much","691":"this","697":"willows","699":"get","702":"longer","708":"watch","709":"meringues","721":"there","733":"do","734":"more","739":"myself","748":"up","765":"understand","772":"and","816":"hook","830":"thing","838":"old","847":"strokes","874":",","879":"it?—confirmed","889":"own","891":"chucked","892":"his","902":"possessed","916":"shook","918":"course","933":"head—“I","972":"until","991":"herself","1002":"in","1037":"eye","1054":"Could","1079":"recover","1086":"faint","1112":"sea","1121":"Why","1141":"Stanley","1159":"escape","1200":"things","1205":"speak","1208":"forget","1225":"questions","1228":"decide","1247":"impossible","1248":"love","1255":"bear","1259":"brain","1271":"to","1283":"fact","1286":"eight","1300":"who","1330":"left","1334":"ideal","1363":"her","1370":"Really","1418":"Mrs.","1420":"fork","1423":"gone","1431":"As","1451":"that","1464":"bed","1482":"sky","1487":"Constantia","1490":"again","1495":"well","1548":"You","1554":"I","1585":"breathe","1586":"punishment","1595":"evening","1624":"bliss","1630":"lean","1633":"us","1635":"Who","1674":"The","1678":"rid","1691":"led","1694":"chest","1742":"She","1751":"cry","1779":"tired","1855":"on","1863":"shuddering","1875":"else","1901":"paying","1935":"what","1942":"anywhere","1944":"Isabel","1957":"What","1960":"still","1970":"sworn","2017":"Neave","2023":"hoping","2031":"sneaking","2052":"wait","2057":"ever","2077":"Jug","2114":"again—“we","2119":"friends","2127":"amount","2134":"these","2183":"wrong","2206":"settle","2239":"she","2241":"”","2256":"far","2258":"take","2290":"meet","2301":"strawberries","2311":"boy","2332":"some","2344":"off","2345":"wondering","2346":"real","2347":"walking","2375":"made","2381":"just","2394":"late","2447":"pretty","2462":"the","2467":"true","2470":"as","2482":"Hennie","2490":"same","2492":"could","2534":"stars","2537":"you","2574":"know","2580":"marry","2594":"chap","2607":"from","2608":"drowsing","2619":"It","2652":"believe","2665":"them","2677":"go","2681":"explain","2683":"kiss","2716":"case","2753":"?","2758":"play","2763":"Or","2774":"reason","2788":"played","2813":"stop","2815":"strange","2842":"disloyal","2869":"neither","2904":"Kate","2925":"....","2927":"say","2944":"difference","2970":"excuse","3053":"forgotten","3067":"keep","3090":"thought","3113":"Hammond","3139":"stern","3149":"agreeing","3157":"added","3163":"conjurer","3170":"everything","3171":"explained","3190":"house","3247":"make","3252":"single","3273":"If","3276":"leave","3289":"Farolles","3300":"little","3304":"so","3324":"eat","3326":"sleep","3354":"was","3394":"taken","3397":"Everybody","3455":"it","3490":"thinking","3496":"Laura","3497":"be","3508":"round","3510":"possibly","3512":"occasions","3534":"Heavens","3542":"plainly","3572":"trust","3595":"anything","3626":"answer","3684":"never","3715":"scarcely","3723":"sat","3744":"Suppose","3754":"hardly","3779":"imagine","3785":"quite","3802":"Was","3832":"further","3844":"Lottie","3847":"before","3880":"cured","3916":"put","3964":"square","3966":"at","4002":"read","4010":"loud","4042":"a","4059":"see","4076":"home","4096":"together","4097":"imagined","4119":"saying","4125":"tragic","4132":"And","4149":"running","4173":"too","4187":"thoughts","4206":"clock","4215":"sitting","4225":"heart","4242":"if","4261":"hide","4264":"with","4270":"been","4292":"got","4316":".","4318":"knowing","4324":"moment","4423":"had","4424":"long","4447":"swim","4449":"no","4475":"any","4505":"throw","4509":"kissed","45 ...
# var examples = [{"doc_id":1,"orth_indices":[[4316,4132,571,2492,5716,2290,1363],[4449,247,571,2492,5716,3964,748],[838,5208,2017,2492,178,5599,3966],[5967,6133,3455,2492,5716,3497,4910],[1901,5607,4667,2492,3497,2788,4264],[4316,5764,2537,2492,3497,103,1002],[4316,2763,2537,2492,2258,748,2332],[1495,5967,588,2492,5716,5953,4042],[2574,2753,5589,2492,5716,251,5473],[5992,4316,5096,2492,5005,5451,4781],[892,2608,1259,2492,5766,318,3354]]},{"doc_id":2,"orth_indices":[[553

# %% [markdown]
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ##### Work with Conc report data using other Python libraries (e.g. Pandas)

# %% [markdown]
# You are not restricted to Conc for your analysis. Conc report data can be exported to other formats. For example, although Conc uses [Polars](https://pola.rs/) internally for its efficiency, you can convert report results into a [Pandas](https://pandas.pydata.org/) dataframe, which is flexible and interoperable with many Python libraries for data analysis. Here is an example ...

# %%
#| eval: false
import pandas as pd # Conc does not require Pandas - so you will need to install it with "pip install pandas"

# %%
#| eval: false
# same specific tokens to restrict the results below to
pronouns = ['i', 'you', 'he', 'she', 'it', 'we', 'they', 'me', 'him', 'her', 'us', 'them', 'mine', 'yours', 
            'his', 'hers', 'its', 'ours', 'yours', 'theirs']

# retrieve keyword report for these pronouns, which has normalized frequencies for each corpus
# the next line returns the result as a Polars dataframe, which is then converted to a Pandas dataframe
df = conc.keywords(restrict_tokens = pronouns).to_frame().to_pandas() # page_size = 0 returns all

# now go for it - do the pandas stuff you are familiar with ...
# e.g. show a table of results ordered by frequency descending
df.sort_values(by='frequency', ascending=False)[['token', 'normalized_frequency', 'normalized_frequency_reference']]
# Out:
#      token  normalized_frequency  normalized_frequency_reference
# 0      she            184.959960                       21.017320
# 7       it            161.267394                       71.326254
# 2      her            147.999558                       29.454856
# 6        i            113.566363                       44.585285
# 12      he            113.408412                       69.091889
# 5      you            101.404179                       33.311432
# 15     his             69.498191                       66.551446
# 9     they             62.864273                       28.995739
# 10    them             33.169591                       18.232015
# 14     him             30.168533                       26.720564
# 8       me             26.535673                       12.049250
# 17      we             21.165358                       22.802772
# 16      us              6.475968                        6.886743
# 18     its              4.264662                       18.160597
# 4     mine              1.895405                        0.591750
# 1     hers              1.105653                        0.163241
# 3    yours              0.947703                        0.244862
# 11    ours              0.473851                        0.265267
# 13  theirs              0.315901                        0.193849

# %% [markdown]
# :::
