# %% [markdown]
# # frequency
#
# > Functionality for frequency analysis.
# - toc: false
# - page-layout: full

# %%
#| default_exp frequency

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
from __future__ import annotations
import time
import polars as pl
from fastcore.basics import patch

# %%
#| export
from conc.corpus import Corpus
from conc.listcorpus import ListCorpus
from conc.result import Result
from conc.core import logger, PAGE_SIZE

# %%
#| hide
from conc.core import set_logger_state

# %%
#| hide
import os

# %%
#| hide
source_path = f'{os.environ.get("HOME")}/data/'
save_path = f'{os.environ.get("HOME")}/data/conc-test-corpora/'

path_to_toy_corpus = f'{save_path}toy.corpus'
path_to_brown_corpus = f'{save_path}brown.corpus'
path_to_brown_listcorpus = f'{save_path}brown.listcorpus'
path_to_reuters_corpus = f'{save_path}reuters.corpus'

# %% [markdown]
# ## Using the Frequency class
#
# There are examples below showing how to use the Frequency class directly to get frequency lists for a corpus. The example below also shows example frequency lists. The recommended way to use this functionality is through the [Conc](https://geoffford.nz/conc/api/conc.html) class. This provides an interface to create frequency lists, concordances, collocation tables, keyword tables and more.

# %% [markdown]
# ## Frequency class API reference

# %%
#| export
class Frequency:
	""" Class for frequency analysis reporting """
	def __init__(self,
			  corpus:Corpus|ListCorpus # Corpus instance
			  ): 
		self.corpus = corpus

# %%
#| hide
# now working from new vocab data structure
brown = Corpus().load(path_to_brown_corpus)
display(brown.vocab.head(5).collect(engine='streaming'))
# Out:
# ┌──────┬───────────────────┬──────────┬───────┬─────────────────┬────────────────┬──────────┬──────────┐
# │ rank ┆ tokens_sort_order ┆ token_id ┆ token ┆ frequency_lower ┆ frequency_orth ┆ is_punct ┆ is_space │
# ╞══════╪═══════════════════╪══════════╪═══════╪═════════════════╪════════════════╪══════════╪══════════╡
# │ 1    ┆ 50087             ┆ 22848    ┆ the   ┆ 63516           ┆ 62473          ┆ false    ┆ false    │
# │ 2    ┆ 28                ┆ 8128     ┆ ,     ┆ 58331           ┆ 58331          ┆ true     ┆ false    │
# │ 3    ┆ 41                ┆ 38309    ┆ .     ┆ 49907           ┆ 49907          ┆ true     ┆ false    │
# │ 4    ┆ 35232             ┆ 2739     ┆ of    ┆ 36321           ┆ 36122          ┆ false    ┆ false    │
# │ 5    ┆ 3351              ┆ 7126     ┆ and   ┆ 27787           ┆ 27633          ┆ false    ┆ false    │
# └──────┴───────────────────┴──────────┴───────┴─────────────────┴────────────────┴──────────┴──────────┘

# %%
#| export
@patch
def frequencies(self: Frequency,
				case_sensitive:bool=False, # frequencies for tokens with or without case preserved 
				normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
				page_size:int=PAGE_SIZE, # number of rows to return, if 0 returns all
				page_current:int=1, # current page, ignored if page_size is 0
				show_token_id:bool=False, # show token_id in output
				show_document_frequency:bool=False, # show document frequency in output
				exclude_tokens:list[str]=[], # exclude specific tokens from frequency report, can be used to remove stopwords
				exclude_tokens_text:str = '', # text to explain which tokens have been excluded, will be added to the report notes
				restrict_tokens:list[str]=[], # restrict frequency report to return frequencies for a list of specific tokens
				restrict_tokens_text:str = '', # text to explain which tokens are included, will be added to the report notes
				exclude_punctuation:bool=True # exclude punctuation tokens
				) -> Result: # return a Result object with the frequency table
	""" Report frequent tokens. """

	if type(normalize_by) != int:
		raise ValueError('normalize_by must be an integer, e.g. 1000000 or 10000')

	start_time = time.time()

	if case_sensitive:
		frequency_column = 'frequency_orth'
		document_count_column = 'orth_index'
		listcorpus_document_count_column = 'document_frequency_orth'
	else:
		frequency_column = 'frequency_lower'
		document_count_column = 'lower_index'
		listcorpus_document_count_column = 'document_frequency_lower'

	if page_size == 0:
		page_current = 1 # if returning all, then only interested in first page

	columns = ['rank', 'token_id', 'token', 'frequency']

	count_tokens, tokens_descriptor, total_descriptor = self.corpus.get_token_count_text(exclude_punctuation)

	formatted_data = []
	formatted_data.append(f'Report based on {tokens_descriptor}')

	df = self.corpus.vocab.filter(pl.col(frequency_column).is_not_null())
	# ALWAYS remove spaces!
	df = df.filter(pl.col('is_space') == False)

	if exclude_tokens:
		excluded_tokens_count = df.filter(pl.col('token').is_in(exclude_tokens)).select(pl.len()).collect(engine='streaming').item()
		df = df.filter(~pl.col('token').is_in(exclude_tokens))
		if exclude_tokens_text == '':
			formatted_data.append(f'Tokens excluded from report: {excluded_tokens_count}')
		else:
			formatted_data.append(f'{exclude_tokens_text}')
			
	if restrict_tokens:
		df = df.filter(pl.col('token').is_in(restrict_tokens))
		if restrict_tokens_text == '':
			formatted_data.append(f'')
		else:
			formatted_data.append(f'{restrict_tokens_text}')

	if exclude_punctuation:
		df = df.filter(pl.col('is_punct') == False)

	df = df.sort(by = frequency_column, descending=True)

	unique_tokens = df.select(pl.len()).collect(engine='streaming').item()

	if page_size == 0:
		rank_offset = 1 # not really needed, but just in case future changes
	else:
		df = df.slice((page_current-1)*page_size, page_size)
		rank_offset = (page_current-1) * page_size+1

	if show_document_frequency:
		columns.append('document_frequency')
		if type(self.corpus) == ListCorpus:
			df = df.with_columns(pl.col(listcorpus_document_count_column).alias('document_frequency'))
		else:
			document_counts = self.corpus.tokens.select(pl.col(document_count_column).alias('token_id'), pl.col('token2doc_index')).group_by('token_id').agg(pl.col('token2doc_index').n_unique().alias('document_frequency'))
			df = df.join(document_counts, on='token_id', how='left', maintain_order='left')

	df = df.rename({frequency_column: "frequency"}).select(*columns)

	df = df.with_columns(((pl.col("frequency") / count_tokens) * normalize_by).alias('normalized_frequency'))
	columns.append('normalized_frequency')

	df = df.drop('rank').with_row_index(name='rank', offset=rank_offset)

	if show_token_id == False:
		df = df.drop('token_id')

	if normalize_by is not None:
		formatted_data.append(f'Normalized Frequency is per {normalize_by:,.0f} tokens')

	formatted_data.append(f'{total_descriptor}: {count_tokens:,.0f}')

	formatted_data.append(f'Unique {tokens_descriptor}: {unique_tokens:,.0f}')
	if page_size != 0 and unique_tokens > page_size:
		formatted_data.append(f'Showing {page_size} rows')
		formatted_data.append(f'Page {page_current} of {unique_tokens // page_size + 1}')

	logger.info(f'Frequencies report time: {(time.time() - start_time):.5f} seconds')

	return Result(type = 'frequencies', df=df, title='Frequencies', description=f'Frequencies of {tokens_descriptor}, {self.corpus.name}', summary_data={}, formatted_data=formatted_data)

# %% [markdown]
# #### Examples
#
# See the note above about accessing this functionality through the [Conc](https://geoffford.nz/conc/api/conc.html) class.

# %%
# load the corpus
brown = Corpus().load(path_to_brown_corpus)

# %%
#| hide
brown_listcorpus = ListCorpus().load(path_to_brown_listcorpus)

# %%
#| hide
toy = Corpus().load(path_to_toy_corpus)

# %%
#| hide
toy.summary()
brown.summary()
# Out:
# <div id="gozibhanzr" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #gozibhanzr table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #gozibhanzr thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #gozibhanzr p { margin: 0; padding: 0; }
#  #gozibhanzr .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #gozibhanzr .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #gozibhanzr .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #gozibhanzr .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #gozibhanzr .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #gozibhanzr .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #gozibhanzr .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #gozibhanzr .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #gozibhanzr .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #gozibhanzr .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #gozibhanzr .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #gozibhanzr .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #gozibhanzr .gt_spanner_row { border-bottom-style: hidden; }
#  #gozibhanzr .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #gozibhanzr .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #gozibhanzr .gt_from_md> :first-child { margin-top: 0; }
#  #gozibhanzr .gt_from_md> :last-child { margin-bottom: 0; }
#  #gozibhanzr .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #gozibhanzr .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #gozibhanzr .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #gozibhanzr .gt_row_group_first td { border-top-width: 2px; }
#  #gozibhanzr .gt_row_group_first th { border-top-width: 2px; }
#  #gozibhanzr .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #gozibhanzr .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #gozibhanzr .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #gozibhanzr .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #gozibhanzr .gt_left { text-align: left; }
#  #gozibhanzr .gt_center { text-align: center; }
#  #gozibhanzr .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #gozibhanzr .gt_font_normal { font-weight: normal; }
#  #gozibhanzr .gt_font_bold { font-weight: bold; }
#  #gozibhanzr .gt_font_italic { font-style: italic; }
#  #gozibhanzr .gt_super { font-size: 65%; }
#  #gozibhanzr .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #gozibhanzr .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Toy Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">Toy corpus is a very small dataset for testing and library development. </td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Date Created</td>
#     <td class="gt_row gt_left">2025-07-10 13:30:02</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Conc Version</td>
#     <td class="gt_row gt_left">0.1.7</td>
#   </tr>
#   <tr>
#     <td class="
# <div id="mxhgttaoey" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #mxhgttaoey table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #mxhgttaoey thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #mxhgttaoey p { margin: 0; padding: 0; }
#  #mxhgttaoey .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #mxhgttaoey .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #mxhgttaoey .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #mxhgttaoey .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #mxhgttaoey .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mxhgttaoey .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #mxhgttaoey .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mxhgttaoey .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #mxhgttaoey .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #mxhgttaoey .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #mxhgttaoey .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #mxhgttaoey .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #mxhgttaoey .gt_spanner_row { border-bottom-style: hidden; }
#  #mxhgttaoey .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #mxhgttaoey .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #mxhgttaoey .gt_from_md> :first-child { margin-top: 0; }
#  #mxhgttaoey .gt_from_md> :last-child { margin-bottom: 0; }
#  #mxhgttaoey .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #mxhgttaoey .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #mxhgttaoey .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #mxhgttaoey .gt_row_group_first td { border-top-width: 2px; }
#  #mxhgttaoey .gt_row_group_first th { border-top-width: 2px; }
#  #mxhgttaoey .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #mxhgttaoey .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #mxhgttaoey .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #mxhgttaoey .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #mxhgttaoey .gt_left { text-align: left; }
#  #mxhgttaoey .gt_center { text-align: center; }
#  #mxhgttaoey .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #mxhgttaoey .gt_font_normal { font-weight: normal; }
#  #mxhgttaoey .gt_font_bold { font-weight: bold; }
#  #mxhgttaoey .gt_font_italic { font-style: italic; }
#  #mxhgttaoey .gt_super { font-size: 65%; }
#  #mxhgttaoey .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #mxhgttaoey .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Brown Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">A Standard Corpus of Present-Day Edited American English, for use with Digital Computers. by W. N. Francis and H. Kucera (1964) Department of Linguistics, Brown University Providence, Rhode Island, USA Revised 1971, Revised and Amplified 1979 http://www.hit.uib.no/icame/brown/bcm.html. This version downloaded via NLTK https://www.

# %%
# instantiate the Frequency class
freq_brown = Frequency(brown)

# %%
#| hide
from conc.corpora import show_toy_corpus

# %%
#| hide
show_toy_corpus(f'{source_path}toy.csv')
# Out:
# <div id="rlyvkqxbpp" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #rlyvkqxbpp table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #rlyvkqxbpp thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #rlyvkqxbpp p { margin: 0; padding: 0; }
#  #rlyvkqxbpp .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #rlyvkqxbpp .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #rlyvkqxbpp .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #rlyvkqxbpp .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #rlyvkqxbpp .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rlyvkqxbpp .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rlyvkqxbpp .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rlyvkqxbpp .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #rlyvkqxbpp .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #rlyvkqxbpp .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #rlyvkqxbpp .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #rlyvkqxbpp .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #rlyvkqxbpp .gt_spanner_row { border-bottom-style: hidden; }
#  #rlyvkqxbpp .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #rlyvkqxbpp .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #rlyvkqxbpp .gt_from_md> :first-child { margin-top: 0; }
#  #rlyvkqxbpp .gt_from_md> :last-child { margin-bottom: 0; }
#  #rlyvkqxbpp .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #rlyvkqxbpp .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #rlyvkqxbpp .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #rlyvkqxbpp .gt_row_group_first td { border-top-width: 2px; }
#  #rlyvkqxbpp .gt_row_group_first th { border-top-width: 2px; }
#  #rlyvkqxbpp .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #rlyvkqxbpp .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rlyvkqxbpp .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rlyvkqxbpp .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #rlyvkqxbpp .gt_left { text-align: left; }
#  #rlyvkqxbpp .gt_center { text-align: center; }
#  #rlyvkqxbpp .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #rlyvkqxbpp .gt_font_normal { font-weight: normal; }
#  #rlyvkqxbpp .gt_font_bold { font-weight: bold; }
#  #rlyvkqxbpp .gt_font_italic { font-style: italic; }
#  #rlyvkqxbpp .gt_super { font-size: 65%; }
#  #rlyvkqxbpp .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #rlyvkqxbpp .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="source">source</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="text">text</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="category">category</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="species">species</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">1.txt</td>
#     <td class="gt_row gt_left">The cat sat on the mat.</td>
#     <td class="gt_row gt_left">feline</td>
#     <td class="gt_row gt_left">cat</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">2.txt</td>
#     <td class="gt_row gt_left">The dog sat on the mat.</td>
#     <td class="gt_row gt_left">canine</td>
#     <td class="gt_row gt_left">dog</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">3.txt</td>
#     <td class="gt_row gt_left">The cat is meowing.</td>
#     <td class="g

# %%
#| hide
freq_toy = Frequency(toy)
frequencies_test = freq_toy.frequencies(normalize_by=100, show_document_frequency = True, page_size=20).to_frame().to_dict(as_series=False)
normalized_frequencies_test = dict(zip(frequencies_test['token'], frequencies_test['normalized_frequency']))
document_frequencies_test = dict(zip(frequencies_test['token'], frequencies_test['document_frequency']))
frequencies_test = dict(zip(frequencies_test['token'], frequencies_test['frequency']))
assert frequencies_test['is'] == 4
assert normalized_frequencies_test['is'] == ((4/32) * 100)
assert document_frequencies_test['is'] == 4

# %time freq_toy.frequencies(normalize_by=100, show_document_frequency = True, page_size=20).display()
# Out:
# <div id="pvfkcrqjtn" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #pvfkcrqjtn table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #pvfkcrqjtn thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #pvfkcrqjtn p { margin: 0; padding: 0; }
#  #pvfkcrqjtn .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #pvfkcrqjtn .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #pvfkcrqjtn .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #pvfkcrqjtn .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #pvfkcrqjtn .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #pvfkcrqjtn .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #pvfkcrqjtn .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #pvfkcrqjtn .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #pvfkcrqjtn .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #pvfkcrqjtn .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #pvfkcrqjtn .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #pvfkcrqjtn .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #pvfkcrqjtn .gt_spanner_row { border-bottom-style: hidden; }
#  #pvfkcrqjtn .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #pvfkcrqjtn .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #pvfkcrqjtn .gt_from_md> :first-child { margin-top: 0; }
#  #pvfkcrqjtn .gt_from_md> :last-child { margin-bottom: 0; }
#  #pvfkcrqjtn .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #pvfkcrqjtn .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #pvfkcrqjtn .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #pvfkcrqjtn .gt_row_group_first td { border-top-width: 2px; }
#  #pvfkcrqjtn .gt_row_group_first th { border-top-width: 2px; }
#  #pvfkcrqjtn .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #pvfkcrqjtn .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #pvfkcrqjtn .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #pvfkcrqjtn .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #pvfkcrqjtn .gt_left { text-align: left; }
#  #pvfkcrqjtn .gt_center { text-align: center; }
#  #pvfkcrqjtn .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #pvfkcrqjtn .gt_font_normal { font-weight: normal; }
#  #pvfkcrqjtn .gt_font_bold { font-weight: bold; }
#  #pvfkcrqjtn .gt_font_italic { font-style: italic; }
#  #pvfkcrqjtn .gt_super { font-size: 65%; }
#  #pvfkcrqjtn .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #pvfkcrqjtn .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="5" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="5" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Toy Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Document-Frequency">Document Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt
# CPU times: user 69.3 ms, sys: 31.9 ms, total: 101 ms
# Wall time: 67.1 ms

# %%
# run the frequencies method and display the results
freq_brown.frequencies(normalize_by=10000, page_size=20).display()
# Out:
# <div id="fghlehkmeh" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #fghlehkmeh table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #fghlehkmeh thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #fghlehkmeh p { margin: 0; padding: 0; }
#  #fghlehkmeh .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #fghlehkmeh .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #fghlehkmeh .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #fghlehkmeh .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #fghlehkmeh .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #fghlehkmeh .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #fghlehkmeh .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #fghlehkmeh .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #fghlehkmeh .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #fghlehkmeh .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #fghlehkmeh .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #fghlehkmeh .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #fghlehkmeh .gt_spanner_row { border-bottom-style: hidden; }
#  #fghlehkmeh .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #fghlehkmeh .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #fghlehkmeh .gt_from_md> :first-child { margin-top: 0; }
#  #fghlehkmeh .gt_from_md> :last-child { margin-bottom: 0; }
#  #fghlehkmeh .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #fghlehkmeh .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #fghlehkmeh .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #fghlehkmeh .gt_row_group_first td { border-top-width: 2px; }
#  #fghlehkmeh .gt_row_group_first th { border-top-width: 2px; }
#  #fghlehkmeh .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #fghlehkmeh .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #fghlehkmeh .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #fghlehkmeh .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #fghlehkmeh .gt_left { text-align: left; }
#  #fghlehkmeh .gt_center { text-align: center; }
#  #fghlehkmeh .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #fghlehkmeh .gt_font_normal { font-weight: normal; }
#  #fghlehkmeh .gt_font_bold { font-weight: bold; }
#  #fghlehkmeh .gt_font_italic { font-style: italic; }
#  #fghlehkmeh .gt_super { font-size: 65%; }
#  #fghlehkmeh .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #fghlehkmeh .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the</td>
#     <td class="gt_row gt_right">63,516</td>
#     <td class="gt_row gt_right">648.03</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_r

# %%
#| hide
freq_brown_listcorpus = Frequency(brown_listcorpus)
freq_brown_listcorpus.frequencies(normalize_by=10000, show_document_frequency = True, page_size=20).display()
# Out:
# <div id="mmgxvqljvs" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #mmgxvqljvs table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #mmgxvqljvs thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #mmgxvqljvs p { margin: 0; padding: 0; }
#  #mmgxvqljvs .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #mmgxvqljvs .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #mmgxvqljvs .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #mmgxvqljvs .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #mmgxvqljvs .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mmgxvqljvs .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #mmgxvqljvs .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mmgxvqljvs .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #mmgxvqljvs .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #mmgxvqljvs .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #mmgxvqljvs .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #mmgxvqljvs .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #mmgxvqljvs .gt_spanner_row { border-bottom-style: hidden; }
#  #mmgxvqljvs .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #mmgxvqljvs .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #mmgxvqljvs .gt_from_md> :first-child { margin-top: 0; }
#  #mmgxvqljvs .gt_from_md> :last-child { margin-bottom: 0; }
#  #mmgxvqljvs .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #mmgxvqljvs .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #mmgxvqljvs .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #mmgxvqljvs .gt_row_group_first td { border-top-width: 2px; }
#  #mmgxvqljvs .gt_row_group_first th { border-top-width: 2px; }
#  #mmgxvqljvs .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #mmgxvqljvs .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #mmgxvqljvs .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #mmgxvqljvs .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #mmgxvqljvs .gt_left { text-align: left; }
#  #mmgxvqljvs .gt_center { text-align: center; }
#  #mmgxvqljvs .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #mmgxvqljvs .gt_font_normal { font-weight: normal; }
#  #mmgxvqljvs .gt_font_bold { font-weight: bold; }
#  #mmgxvqljvs .gt_font_italic { font-style: italic; }
#  #mmgxvqljvs .gt_super { font-size: 65%; }
#  #mmgxvqljvs .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #mmgxvqljvs .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="5" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="5" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Document-Frequency">Document Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row

# %%
#| hide
# test page 2
freq_brown.frequencies(normalize_by=10000, page_current = 2, page_size=20).display()
# Out:
# <div id="bsgritkoyt" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #bsgritkoyt table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #bsgritkoyt thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #bsgritkoyt p { margin: 0; padding: 0; }
#  #bsgritkoyt .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #bsgritkoyt .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #bsgritkoyt .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #bsgritkoyt .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #bsgritkoyt .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #bsgritkoyt .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #bsgritkoyt .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #bsgritkoyt .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #bsgritkoyt .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #bsgritkoyt .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #bsgritkoyt .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #bsgritkoyt .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #bsgritkoyt .gt_spanner_row { border-bottom-style: hidden; }
#  #bsgritkoyt .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #bsgritkoyt .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #bsgritkoyt .gt_from_md> :first-child { margin-top: 0; }
#  #bsgritkoyt .gt_from_md> :last-child { margin-bottom: 0; }
#  #bsgritkoyt .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #bsgritkoyt .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #bsgritkoyt .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #bsgritkoyt .gt_row_group_first td { border-top-width: 2px; }
#  #bsgritkoyt .gt_row_group_first th { border-top-width: 2px; }
#  #bsgritkoyt .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #bsgritkoyt .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #bsgritkoyt .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #bsgritkoyt .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #bsgritkoyt .gt_left { text-align: left; }
#  #bsgritkoyt .gt_center { text-align: center; }
#  #bsgritkoyt .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #bsgritkoyt .gt_font_normal { font-weight: normal; }
#  #bsgritkoyt .gt_font_bold { font-weight: bold; }
#  #bsgritkoyt .gt_font_italic { font-style: italic; }
#  #bsgritkoyt .gt_super { font-size: 65%; }
#  #bsgritkoyt .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #bsgritkoyt .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">21</td>
#     <td class="gt_row gt_left">at</td>
#     <td class="gt_row gt_right">4,990</td>
#     <td class="gt_row gt_right">50.91</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_rig

# %%
from conc.core import get_stop_words

# %%
stop_words = get_stop_words(save_path, spacy_model = 'en_core_web_sm')
freq_brown.frequencies(normalize_by=10000, show_document_frequency = True, exclude_tokens = stop_words, page_size=20).display()
# Out:
# <div id="ukdrfghanj" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ukdrfghanj table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ukdrfghanj thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ukdrfghanj p { margin: 0; padding: 0; }
#  #ukdrfghanj .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ukdrfghanj .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ukdrfghanj .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #ukdrfghanj .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #ukdrfghanj .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ukdrfghanj .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ukdrfghanj .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ukdrfghanj .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ukdrfghanj .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ukdrfghanj .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ukdrfghanj .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ukdrfghanj .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ukdrfghanj .gt_spanner_row { border-bottom-style: hidden; }
#  #ukdrfghanj .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ukdrfghanj .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ukdrfghanj .gt_from_md> :first-child { margin-top: 0; }
#  #ukdrfghanj .gt_from_md> :last-child { margin-bottom: 0; }
#  #ukdrfghanj .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ukdrfghanj .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ukdrfghanj .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ukdrfghanj .gt_row_group_first td { border-top-width: 2px; }
#  #ukdrfghanj .gt_row_group_first th { border-top-width: 2px; }
#  #ukdrfghanj .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #ukdrfghanj .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ukdrfghanj .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ukdrfghanj .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ukdrfghanj .gt_left { text-align: left; }
#  #ukdrfghanj .gt_center { text-align: center; }
#  #ukdrfghanj .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ukdrfghanj .gt_font_normal { font-weight: normal; }
#  #ukdrfghanj .gt_font_bold { font-weight: bold; }
#  #ukdrfghanj .gt_font_italic { font-style: italic; }
#  #ukdrfghanj .gt_super { font-size: 65%; }
#  #ukdrfghanj .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ukdrfghanj .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="5" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="5" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Document-Frequency">Document Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized-Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row

# %%
#| hide
# IMPORTANT: the following code is commented out to avoid running it in CI, uncomment to run locally
# congress = Corpus().load(f'{save_path}us-congressional-speeches-subset-100k.corpus')
# freq_congress = Frequency(congress)
# %time freq_congress.frequencies(normalize_by=10000, page_size=20).display()
# bnc = Corpus().load(f'{save_path}bnc.corpus')
# freq_bnc = Frequency(bnc)
# freq_bnc.frequencies(normalize_by=10000, page_size=20).display()

# # count and frequency of vocab table with frequency > 4
# display(freq_bnc.frequencies(normalize_by=10000, page_size=0).to_frame().filter(pl.col('frequency') > 4).select(pl.len()).item())
# display(freq_bnc.frequencies(normalize_by=10000, page_size=0).to_frame().filter(pl.col('frequency') > 4).select(pl.len()).item() / freq_bnc.frequencies(normalize_by=10000, page_size=0).to_frame().select(pl.len()).item())

# %%
#| hide
import nbdev; nbdev.nbdev_export()
