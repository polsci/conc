# %% [markdown]
# # conc
#
# > An interface to create Conc reports for corpus linguistic analysis of frequency, concordances, ngrams, keyness, and collocation.
# - toc: false
# - page-layout: full

# %%
#| default_exp conc

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
from __future__ import annotations
import time
from fastcore.basics import patch

# %%
#| export
from conc.result import Result
from conc.core import PAGE_SIZE, logger
from conc.corpus import Corpus
from conc.frequency import Frequency
from conc.ngrams import Ngrams
from conc.concordance import Concordance
from conc.keyness import Keyness
from conc.collocates import Collocates

# %%
#| hide
from conc.core import set_logger_state

# %%
#| hide
import os

# %%
#| hide
source_path = f'{os.environ.get("HOME")}/data/'
save_path = f'{os.environ.get("HOME")}/data/conc-test-corpora/'

path_to_toy_corpus = f'{save_path}toy.corpus'
path_to_brown_corpus = f'{save_path}brown.corpus'
path_to_reuters_corpus = f'{save_path}reuters.corpus'

# %%
#| export
class Conc:
	"""Unified interface to Conc reporting for analysis of frequency, ngrams, concordances, keyness, and collocates."""
	
	def __init__(self, 
				corpus # Corpus instance
				):
		# information about corpus
		self.corpus = corpus
		self.frequency_ = Frequency(corpus)
		self.ngrams_ = Ngrams(corpus)
		self.concordance_ = Concordance(corpus)
		self.keyness_ = None
		self.collocates_ = Collocates(corpus)

# %%
# load (or build) a corpus
reuters = Corpus('reuters').load(path_to_reuters_corpus)

# %%
#get a summary
reuters.summary()
# Out:
# <div id="ssurahgjoc" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ssurahgjoc table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ssurahgjoc thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ssurahgjoc p { margin: 0; padding: 0; }
#  #ssurahgjoc .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ssurahgjoc .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ssurahgjoc .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #ssurahgjoc .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #ssurahgjoc .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ssurahgjoc .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ssurahgjoc .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ssurahgjoc .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ssurahgjoc .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ssurahgjoc .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ssurahgjoc .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ssurahgjoc .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ssurahgjoc .gt_spanner_row { border-bottom-style: hidden; }
#  #ssurahgjoc .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ssurahgjoc .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ssurahgjoc .gt_from_md> :first-child { margin-top: 0; }
#  #ssurahgjoc .gt_from_md> :last-child { margin-bottom: 0; }
#  #ssurahgjoc .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ssurahgjoc .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ssurahgjoc .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ssurahgjoc .gt_row_group_first td { border-top-width: 2px; }
#  #ssurahgjoc .gt_row_group_first th { border-top-width: 2px; }
#  #ssurahgjoc .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #ssurahgjoc .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ssurahgjoc .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ssurahgjoc .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ssurahgjoc .gt_left { text-align: left; }
#  #ssurahgjoc .gt_center { text-align: center; }
#  #ssurahgjoc .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ssurahgjoc .gt_font_normal { font-weight: normal; }
#  #ssurahgjoc .gt_font_bold { font-weight: bold; }
#  #ssurahgjoc .gt_font_italic { font-style: italic; }
#  #ssurahgjoc .gt_super { font-size: 65%; }
#  #ssurahgjoc .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ssurahgjoc .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Reuters Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">Reuters corpus (Reuters-21578, Distribution 1.0). "The copyright for the text of newswire articles and Reuters annotations in the Reuters-21578 collection resides with Reuters Ltd. Reuters Ltd. and Carnegie Group, Inc. have agreed to allow the free distribution of this data *for research purposes only*. If you publish results ba

# %%
# create a Conc report instance for the corpus
conc = Conc(reuters)

# %%
#| export
@patch
def frequencies(self: Conc,
				case_sensitive:bool=False, # frequencies for tokens with or without case preserved 
				normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
				page_size:int=PAGE_SIZE, # number of rows to return, if 0 returns all
				page_current:int=1, # current page, ignored if page_size is 0
				show_token_id:bool=False, # show token_id in output
				show_document_frequency:bool=False, # show document frequency in output
				exclude_tokens:list[str]=[], # exclude specific tokens from frequency report, can be used to remove stopwords
				exclude_tokens_text:str = '', # text to explain which tokens have been excluded, will be added to the report notes
				restrict_tokens:list[str]=[], # restrict frequency report to return frequencies for a list of specific tokens
				restrict_tokens_text:str = '', # text to explain which tokens are included, will be added to the report notes
				exclude_punctuation:bool=True # exclude punctuation tokens
				) -> Result: # return a Result object with the frequency table
	""" Report frequent tokens. """
	return self.frequency_.frequencies(case_sensitive=case_sensitive,
										normalize_by=normalize_by,
										page_size=page_size,
										page_current=page_current,
										show_token_id=show_token_id,
										show_document_frequency=show_document_frequency,
										exclude_tokens=exclude_tokens,
										exclude_tokens_text=exclude_tokens_text,
										restrict_tokens=restrict_tokens,
										restrict_tokens_text=restrict_tokens_text,
										exclude_punctuation=exclude_punctuation)

# %%
#| hide
# said mentioned 25379

# %%
conc.frequencies(normalize_by=10000).display()
# Out:
# <div id="jhzbbyuwsd" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #jhzbbyuwsd table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #jhzbbyuwsd thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #jhzbbyuwsd p { margin: 0; padding: 0; }
#  #jhzbbyuwsd .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #jhzbbyuwsd .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #jhzbbyuwsd .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #jhzbbyuwsd .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #jhzbbyuwsd .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jhzbbyuwsd .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jhzbbyuwsd .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jhzbbyuwsd .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #jhzbbyuwsd .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #jhzbbyuwsd .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #jhzbbyuwsd .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #jhzbbyuwsd .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #jhzbbyuwsd .gt_spanner_row { border-bottom-style: hidden; }
#  #jhzbbyuwsd .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #jhzbbyuwsd .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #jhzbbyuwsd .gt_from_md> :first-child { margin-top: 0; }
#  #jhzbbyuwsd .gt_from_md> :last-child { margin-bottom: 0; }
#  #jhzbbyuwsd .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #jhzbbyuwsd .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #jhzbbyuwsd .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #jhzbbyuwsd .gt_row_group_first td { border-top-width: 2px; }
#  #jhzbbyuwsd .gt_row_group_first th { border-top-width: 2px; }
#  #jhzbbyuwsd .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #jhzbbyuwsd .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jhzbbyuwsd .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #jhzbbyuwsd .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #jhzbbyuwsd .gt_left { text-align: left; }
#  #jhzbbyuwsd .gt_center { text-align: center; }
#  #jhzbbyuwsd .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #jhzbbyuwsd .gt_font_normal { font-weight: normal; }
#  #jhzbbyuwsd .gt_font_bold { font-weight: bold; }
#  #jhzbbyuwsd .gt_font_italic { font-style: italic; }
#  #jhzbbyuwsd .gt_super { font-size: 65%; }
#  #jhzbbyuwsd .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #jhzbbyuwsd .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the</td>
#     <td class="gt_row gt_right">69,263</td>
#     <td class="gt_row gt_right">495.17</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt

# %%
#| export
@patch
def ngrams(self: Conc, 
		   token_str: str, # token string to get ngrams for 
		   ngram_length:int = 2, # length of ngram
		   ngram_token_position: str = 'LEFT', # specify if token sequence is on LEFT or RIGHT (support for ngrams with token in middle of sequence is in-development))
		   normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
		   page_size:int = PAGE_SIZE, # number of results to display per results page 
		   page_current:int = 1, # current page of results
		   show_all_columns:bool = False, # return raw df with all columns or just ngram and frequency
		   exclude_punctuation:bool=True, # do not return ngrams with punctuation tokens
		   use_cache:bool = True # retrieve the results from cache if available
		   ) -> Result: # return a Result object with ngram data
	""" Report ngram frequencies containing a token string. """

	return self.ngrams_.ngrams(token_str, 
							ngram_length=ngram_length, 
							ngram_token_position=ngram_token_position, 
							normalize_by=normalize_by,
							page_size=page_size, 
							page_current=page_current, 
							show_all_columns=show_all_columns, 
							exclude_punctuation=exclude_punctuation,
							use_cache=use_cache)

# %%
#| hide
# said mentioned 25,379 from above - matches count 25,379 for bigrams ... 
# conc.ngrams(token_str = 'said', ngram_length = 2, ngram_token_position = 'LEFT', exclude_punctuation = False, page_size = 5).display()
# if change to trigrams - get different count 25,355 - this is due to EOF removal
set_logger_state('verbose')
conc.ngrams(token_str = 'said', ngram_length = 3, ngram_token_position = 'RIGHT', exclude_punctuation = True, page_size = 5).display()
set_logger_state('quiet')
# the company said ngram shown as 1,173
# Out:
# 2025-06-13 15:44:26 - INFO - _init_token_arrays - Created tokens_array in 0.011 seconds
# 2025-06-13 15:44:26 - INFO - _init_token_arrays - Created tokens_lookup in 0.005 seconds
# 2025-06-13 15:44:26 - INFO - _init_token_arrays - Created tokens_sort_order in 0.007 seconds
# 2025-06-13 15:44:26 - INFO - tokenize - Tokenization time: 0.02568 seconds
# 2025-06-13 15:44:26 - INFO - get_token_positions - Token indexing (25379) time: 0.00759 seconds
# 2025-06-13 15:44:26 - INFO - ngrams - Generating ngrams results
# 2025-06-13 15:44:26 - INFO - get_tokens_in_context - Context tokens collected: (3, 25379)
# 2025-06-13 15:44:26 - INFO - get_tokens_in_context - Context retrieved in 0.06 seconds.
# 2025-06-13 15:44:26 - DEBUG - _get_ngrams - Ngrams shape prior to EOF removal (3, 25379)
# 2025-06-13 15:44:26 - DEBUG - _get_ngrams - Ngrams shape after EOF removal (3, 25355)
# 2025-06-13 15:44:26 - INFO - _get_ngrams - Ngrams (12707) retrieval time: 0.06642 seconds
# 2025-06-13 15:44:26 - INFO - ngrams - Ngrams report time: 0.07777 seconds
# <div id="eejbchsxxn" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #eejbchsxxn table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #eejbchsxxn thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #eejbchsxxn p { margin: 0; padding: 0; }
#  #eejbchsxxn .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #eejbchsxxn .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #eejbchsxxn .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #eejbchsxxn .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #eejbchsxxn .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #eejbchsxxn .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #eejbchsxxn .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #eejbchsxxn .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #eejbchsxxn .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #eejbchsxxn .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #eejbchsxxn .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #eejbchsxxn .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #eejbchsxxn .gt_spanner_row { border-bottom-style: hidden; }
#  #eejbchsxxn .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #eejbchsxxn .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #eejbchsxxn .gt_from_md> :first-child { margin-top: 0; }
#  #eejbchsxxn .gt_from_md> :last-child { margin-bottom: 0; }
#  #eejbchsxxn .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #eejbchsxxn .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #eejbchsxxn .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #eejbchsxxn .gt_row_group_first td { border-top-width: 2px; }
#  #eejbchsxxn .gt_row_group_first th { border-top-width: 2px; }
#  #eejbchsxxn .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #eejbchsxxn .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #eejbchsxxn .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #eejbchsxxn .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #eejbchsxxn .gt_left { text-align: left; }
#  #eejbchsxxn .gt_center { text-align: center; }
#  #eejbchsxxn .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #eejbchsxxn .gt_font_normal { font-weight: normal; }
#  #eejbchsxxn .gt_font_bold { font-weight: bold; }
#  #eejbchsxxn .gt_font_italic { font-style: italic; }
#  #eejbchsxxn .gt_super { font-size: 65%; }
#  #eejbchsxxn .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #eejbchsxxn .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngrams for &quot;said&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_r

# %%
conc.ngrams(token_str = 'said', ngram_length = 3, ngram_token_position = 'RIGHT', exclude_punctuation = True).display()
# Out:
# <div id="hkbtcsqohw" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #hkbtcsqohw table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #hkbtcsqohw thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #hkbtcsqohw p { margin: 0; padding: 0; }
#  #hkbtcsqohw .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #hkbtcsqohw .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #hkbtcsqohw .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #hkbtcsqohw .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #hkbtcsqohw .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hkbtcsqohw .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hkbtcsqohw .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hkbtcsqohw .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #hkbtcsqohw .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #hkbtcsqohw .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #hkbtcsqohw .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #hkbtcsqohw .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #hkbtcsqohw .gt_spanner_row { border-bottom-style: hidden; }
#  #hkbtcsqohw .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #hkbtcsqohw .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #hkbtcsqohw .gt_from_md> :first-child { margin-top: 0; }
#  #hkbtcsqohw .gt_from_md> :last-child { margin-bottom: 0; }
#  #hkbtcsqohw .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #hkbtcsqohw .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #hkbtcsqohw .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #hkbtcsqohw .gt_row_group_first td { border-top-width: 2px; }
#  #hkbtcsqohw .gt_row_group_first th { border-top-width: 2px; }
#  #hkbtcsqohw .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #hkbtcsqohw .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hkbtcsqohw .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #hkbtcsqohw .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #hkbtcsqohw .gt_left { text-align: left; }
#  #hkbtcsqohw .gt_center { text-align: center; }
#  #hkbtcsqohw .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #hkbtcsqohw .gt_font_normal { font-weight: normal; }
#  #hkbtcsqohw .gt_font_bold { font-weight: bold; }
#  #hkbtcsqohw .gt_font_italic { font-style: italic; }
#  #hkbtcsqohw .gt_super { font-size: 65%; }
#  #hkbtcsqohw .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #hkbtcsqohw .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngrams for &quot;said&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_r

# %%
#| export
@patch
def ngram_frequencies(self: Conc, 
                ngram_length:int=2, # length of ngram
                case_sensitive:bool=False, # frequencies for tokens lowercased or with case preserved
				normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
				page_size:int=PAGE_SIZE, # number of rows to return
				page_current:int=1, # current page
				exclude_punctuation:bool=True # exclude ngrams containing punctuation tokens
				) -> Result: # return a Result object with the frequency table
    """ Report frequent ngrams. """
    return self.ngrams_.ngram_frequencies(ngram_length=ngram_length,
                                    case_sensitive=case_sensitive,
                                    normalize_by=normalize_by,
                                    page_size=page_size,
                                    page_current=page_current,
                                    exclude_punctuation=exclude_punctuation)

# %%
#| hide
# "the company said" = 1,173 - matches above count
conc.ngram_frequencies(ngram_length = 3, case_sensitive = False, exclude_punctuation = True, page_size = 10).display()
# Out:
# <div id="eevspejyvz" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #eevspejyvz table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #eevspejyvz thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #eevspejyvz p { margin: 0; padding: 0; }
#  #eevspejyvz .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #eevspejyvz .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #eevspejyvz .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #eevspejyvz .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #eevspejyvz .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #eevspejyvz .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #eevspejyvz .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #eevspejyvz .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #eevspejyvz .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #eevspejyvz .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #eevspejyvz .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #eevspejyvz .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #eevspejyvz .gt_spanner_row { border-bottom-style: hidden; }
#  #eevspejyvz .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #eevspejyvz .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #eevspejyvz .gt_from_md> :first-child { margin-top: 0; }
#  #eevspejyvz .gt_from_md> :last-child { margin-bottom: 0; }
#  #eevspejyvz .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #eevspejyvz .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #eevspejyvz .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #eevspejyvz .gt_row_group_first td { border-top-width: 2px; }
#  #eevspejyvz .gt_row_group_first th { border-top-width: 2px; }
#  #eevspejyvz .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #eevspejyvz .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #eevspejyvz .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #eevspejyvz .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #eevspejyvz .gt_left { text-align: left; }
#  #eevspejyvz .gt_center { text-align: center; }
#  #eevspejyvz .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #eevspejyvz .gt_font_normal { font-weight: normal; }
#  #eevspejyvz .gt_font_bold { font-weight: bold; }
#  #eevspejyvz .gt_font_italic { font-style: italic; }
#  #eevspejyvz .gt_super { font-size: 65%; }
#  #eevspejyvz .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #eevspejyvz .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngram Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_right">2</t

# %%
conc.ngram_frequencies(ngram_length = 3, case_sensitive = False, exclude_punctuation = True, page_current = 1).display()
# Out:
# <div id="ugiijkvivz" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ugiijkvivz table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ugiijkvivz thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ugiijkvivz p { margin: 0; padding: 0; }
#  #ugiijkvivz .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ugiijkvivz .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ugiijkvivz .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #ugiijkvivz .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #ugiijkvivz .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ugiijkvivz .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ugiijkvivz .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ugiijkvivz .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ugiijkvivz .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ugiijkvivz .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ugiijkvivz .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ugiijkvivz .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ugiijkvivz .gt_spanner_row { border-bottom-style: hidden; }
#  #ugiijkvivz .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ugiijkvivz .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ugiijkvivz .gt_from_md> :first-child { margin-top: 0; }
#  #ugiijkvivz .gt_from_md> :last-child { margin-bottom: 0; }
#  #ugiijkvivz .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ugiijkvivz .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ugiijkvivz .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ugiijkvivz .gt_row_group_first td { border-top-width: 2px; }
#  #ugiijkvivz .gt_row_group_first th { border-top-width: 2px; }
#  #ugiijkvivz .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #ugiijkvivz .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ugiijkvivz .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ugiijkvivz .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ugiijkvivz .gt_left { text-align: left; }
#  #ugiijkvivz .gt_center { text-align: center; }
#  #ugiijkvivz .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ugiijkvivz .gt_font_normal { font-weight: normal; }
#  #ugiijkvivz .gt_font_bold { font-weight: bold; }
#  #ugiijkvivz .gt_font_italic { font-style: italic; }
#  #ugiijkvivz .gt_super { font-size: 65%; }
#  #ugiijkvivz .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ugiijkvivz .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngram Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_right">2</t

# %%
#| export
@patch
def concordance(self: Conc, 
				token_str: str, # token string to get concordance for 
				context_length:int = 5, # number of words to show on left and right of token string
				order:str='1R2R3R', # order of sort columns
				page_size:int=PAGE_SIZE, # number of results to display per results page
				page_current:int=1, # current page of results
				show_all_columns:bool = False, # df with all columns or just essentials
				use_cache:bool = True # retrieve the results from cache if available (currently ignored)
				) -> Result: # concordance report results
	""" Report concordance for a token string. """
	return self.concordance_.concordance(token_str = token_str, 
									  context_length=context_length, 
									  order=order, page_size=page_size, 
									  page_current=page_current, 
									  show_all_columns=show_all_columns, 
									  use_cache=use_cache)

# %%
#| hide
# Total Concordance Lines for "said" is correct - 25379
# "the company said" 1173

# %%
conc.concordance('the company said', context_length = 5, order='1R2R3R').display()
# Out:
# <div id="jgkfwkhdwf" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #jgkfwkhdwf table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #jgkfwkhdwf thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #jgkfwkhdwf p { margin: 0; padding: 0; }
#  #jgkfwkhdwf .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #jgkfwkhdwf .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #jgkfwkhdwf .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #jgkfwkhdwf .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #jgkfwkhdwf .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jgkfwkhdwf .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jgkfwkhdwf .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jgkfwkhdwf .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #jgkfwkhdwf .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #jgkfwkhdwf .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #jgkfwkhdwf .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #jgkfwkhdwf .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #jgkfwkhdwf .gt_spanner_row { border-bottom-style: hidden; }
#  #jgkfwkhdwf .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #jgkfwkhdwf .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #jgkfwkhdwf .gt_from_md> :first-child { margin-top: 0; }
#  #jgkfwkhdwf .gt_from_md> :last-child { margin-bottom: 0; }
#  #jgkfwkhdwf .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #jgkfwkhdwf .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #jgkfwkhdwf .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #jgkfwkhdwf .gt_row_group_first td { border-top-width: 2px; }
#  #jgkfwkhdwf .gt_row_group_first th { border-top-width: 2px; }
#  #jgkfwkhdwf .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #jgkfwkhdwf .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jgkfwkhdwf .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #jgkfwkhdwf .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #jgkfwkhdwf .gt_left { text-align: left; }
#  #jgkfwkhdwf .gt_center { text-align: center; }
#  #jgkfwkhdwf .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #jgkfwkhdwf .gt_font_normal { font-weight: normal; }
#  #jgkfwkhdwf .gt_font_bold { font-weight: bold; }
#  #jgkfwkhdwf .gt_font_italic { font-style: italic; }
#  #jgkfwkhdwf .gt_super { font-size: 65%; }
#  #jgkfwkhdwf .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #jgkfwkhdwf .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Concordance for &quot;the company said&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus, Context tokens: 5, Order: 1R2R3R</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Document Id">Document Id</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Left">Left</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Node">Node</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Right">Right</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">2,744</td>
#     <td class="gt_row gt_right">through a tender offer .</td>
#     <td class="gt_row gt_left">The company said</td>
#     <td class="gt_row gt_left">" The n

# %%
#| export
@patch
def concordance_plot(self: Conc,
				token_str: str, # token string for concordance plot
				page_size: int = 10, # number of plots per page
				append_info: bool = True # append token position info to the concordance line preview screens visible when hover over the plot lines
				):
	"""Display a concordance plot."""
	return self.concordance_.concordance_plot(token_str=token_str,
												page_size=page_size,
												append_info=append_info)

# %%
conc.concordance_plot('cause', page_size=10)
# Out:
# <!doctype html>
# 	<html lang="en">
# 	<head>
# 		<meta charset="UTF-8"><title>Conc Plot</title>
# 	<script>
# var eof_token = 63132;
# var page_size = 10;
# var append_info = true;
# var row_height = 60;
# var start_first_row_at = 30;
# var row_adjustment = 30;
# var default_font_size = 12;
# var subplot_height = 40;
# var plot_height = 610;
# var plot_x = 160;
# var label_x_right = 150;
# var docs = [{"doc_id":19,"positions":[444],"count":496},{"doc_id":112,"positions":[94],"count":700},{"doc_id":204,"positions":[77],"count":215},{"doc_id":220,"positions":[356],"count":601},{"doc_id":280,"positions":[151],"count":668},{"doc_id":291,"positions":[238],"count":331},{"doc_id":388,"positions":[619],"count":679},{"doc_id":432,"positions":[349],"count":501},{"doc_id":445,"positions":[662],"count":672},{"doc_id":618,"positions":[61],"count":216},{"doc_id":651,"positions":[37],"count":118},{"doc_id":690,"positions":[663],"count":960},{"doc_id":1158,"positions":[46],"count":308},{"doc_id":1222,"positions":[290],"count":447},{"doc_id":1491,"positions":[4,23,88],"count":264},{"doc_id":1669,"positions":[151],"count":202},{"doc_id":1740,"positions":[371],"count":533},{"doc_id":1776,"positions":[101],"count":109},{"doc_id":1785,"positions":[99],"count":107},{"doc_id":1802,"positions":[148,334],"count":426},{"doc_id":1864,"positions":[239],"count":305},{"doc_id":2136,"positions":[127],"count":208},{"doc_id":2195,"positions":[365],"count":509},{"doc_id":2235,"positions":[77],"count":128},{"doc_id":2238,"positions":[9,21],"count":23},{"doc_id":2242,"positions":[5,18,58],"count":533},{"doc_id":2244,"positions":[218],"count":306},{"doc_id":2260,"positions":[73],"count":123},{"doc_id":2336,"positions":[353],"count":703},{"doc_id":2466,"positions":[486],"count":708},{"doc_id":2614,"positions":[54],"count":207},{"doc_id":3177,"positions":[205],"count":684},{"doc_id":3180,"positions":[210],"count":572},{"doc_id":3238,"positions":[299],"count":922},{"doc_id":3274,"positions":[348],"count":657},{"doc_id":3460,"positions":[391],"count":845},{"doc_id":3484,"positions":[177],"count":190},{"doc_id":3515,"positions":[113],"count":125},{"doc_id":3517,"positions":[391],"count":845},{"doc_id":3623,"positions":[142],"count":174},{"doc_id":3733,"positions":[180],"count":245},{"doc_id":3839,"positions":[286],"count":375},{"doc_id":3988,"positions":[266],"count":532},{"doc_id":4127,"positions":[78],"count":111},{"doc_id":4150,"positions":[631],"count":644},{"doc_id":4297,"positions":[169],"count":339},{"doc_id":4328,"positions":[472],"count":705},{"doc_id":4381,"positions":[11],"count":127},{"doc_id":4403,"positions":[71],"count":164},{"doc_id":4409,"positions":[271],"count":463},{"doc_id":4595,"positions":[203],"count":229},{"doc_id":4611,"positions":[169],"count":264},{"doc_id":4643,"positions":[91],"count":98},{"doc_id":4853,"positions":[139],"count":166},{"doc_id":4916,"positions":[57],"count":73},{"doc_id":5091,"positions":[163],"count":277},{"doc_id":5160,"positions":[153],"count":326},{"doc_id":5168,"positions":[360],"count":756},{"doc_id":5380,"positions":[11,24],"count":25},{"doc_id":5393,"positions":[29,102],"count":129},{"doc_id":5539,"positions":[103],"count":552},{"doc_id":5578,"positions":[26,143],"count":570},{"doc_id":5614,"positions":[642],"count":738},{"doc_id":5655,"positions":[259],"count":518},{"doc_id":5717,"positions":[192,356],"count":547},{"doc_id":5815,"positions":[161],"count":206},{"doc_id":5864,"positions":[642],"count":740},{"doc_id":6094,"positions":[102],"count":148},{"doc_id":6163,"positions":[2],"count":456},{"doc_id":6215,"positions":[480],"count":509},{"doc_id":6223,"positions":[190],"count":353},{"doc_id":6227,"positions":[92],"count":187},{"doc_id":6283,"positions":[260],"count":426},{"doc_id":6357,"positions":[398],"count":815},{"doc_id":6437,"positions":[227],"count":296},{"doc_id":6451,"positions":[350],"count":562},{"doc_id":6565,"positions":[110],"count":342},{"doc_id":6566,"positions":[269],"count":429},{"doc_id":7037,"positions":[92],"count":378},{"doc_id":7134,"positions":[125],"count":252},{"doc_id":7246,"positions":[221],"count":749},{"doc_id":7328,"positions":[417],"count":714},{"doc_id":7344,"positions":[472],"count":850},{"doc_id":7550,"positions":[374],"count":490},{"doc_id":7664,"positions":[129],"count":476},{"doc_id":7671,"positions":[202],"count":321},{"doc_id":7884,"positions":[140],"count":5 ...
# var tokens = {"24":"number","27":"root","111":"designed","400":"loss","405":"lead","546":"Netherlands","631":"fire","638":"present","791":"salmonella","1050":"acreages","1940":"not","2016":"gap","2200":"drop","2568":"less","2997":"reevaluate","3021":"SALMONELLA","3280":"CAUSE","3445":"delay","3805":"of","4821":"delegate","5240":"increase","5358":"war","5553":"rise","5863":"plummet","5999":"explosion","6230":"Center","6858":"panic","6931":"he","7482":"inflows","7553":"disruption","7971":"policy","8083":"establish","8137":"output","8284":"this","8459":"longer","8478":"investments","8558":"housing","8591":"production","8969":"more","9410":"RISES","9421":"personnel","9490":"and","9586":"cause","9622":"hardship","9788":"forfeitures","10014":"depressions","10530":"El","10696":"provisiion","10743":",","10962":"private","10982":"retaliation","11365":"basic","11383":"INFLATION","11395":"large","11525":"depressed","11535":"embarrassment","11589":"March","12053":"until","12378":"threaten","12439":"in","12781":"extinguished","12918":"deterioration","13258":"issuers","13321":"falls","13596":"MAJOR","13638":"combination","14086":"is","14843":"extraordinary","15155":"nor","15460":"or","15684":"to","16352":"primary","16437":"change","16944":"ATPC","16949":"February","17121":"disinflation","17469":"rising","17555":"their","17920":"foreign","17923":"act","18130":"that","18133":"investors","18472":"continues","18485":"problem","18690":"term","19222":"bonds","19475":"without","19499":"base","19728":"gave","19769":"saturated","20173":"nation","20407":"rises","20488":"us","20751":"are","20939":"The","21390":"3.2","21619":"those","22529":"imports","22581":"reserves","22691":"warship","23006":"idea","23108":"next","23321":"on","23827":"slack","23951":"disease","24425":"Noranda","24482":"alarm","24707":"dollar","24940":"firm","25223":"There","25308":"recession","25728":"directors","25906":"rain","26387":"RATE","26685":"these","26770":"dislocation","26788":"start","26827":"damage","27038":"collateral","27108":"voting","27293":"full","27315":"

# %%
#| export
@patch
def set_reference_corpus(self: Conc, 
                    corpus: Corpus  # Reference corpus
                    ) -> None:
    """ Set a reference corpus for keyness analysis. """
    self.keyness_ = Keyness(self.corpus, corpus)

# %%
# load a corpus as a reference corpus
brown = Corpus('brown').load(path_to_brown_corpus)

# set corpus as reference corpus
conc.set_reference_corpus(brown)

# %%
#| export
@patch
def keywords(self: Conc,
				effect_size_measure:str = 'log_ratio', # effect size measure to use, currently only 'log_ratio' is supported
				statistical_significance_measure:str = 'log_likelihood', # statistical significance measure to use, currently only 'log_likelihood' is supported
				order:str|None = None, # default of None orders by effect size measure, results can also be ordered by: frequency, frequency_reference, document_frequency, document_frequency_reference, log_likelihood
				order_descending:bool = True, # order is descending or ascending
				statistical_significance_cut: float|None = None, # statistical significance p-value to filter results, e.g. 0.05 or 0.01 or 0.001 - ignored if None or 0
				apply_bonferroni:bool = False, # apply Bonferroni correction to the statistical significance cut-off
				min_document_frequency: int = 0, # minimum document frequency in target for token to be included in the report
				min_document_frequency_reference: int = 0, # minimum document frequency in reference for token to be included in the report
				min_frequency: int = 0, # minimum frequency in target for token to be included in the report
				min_frequency_reference: int = 0, # minimum document frequency in reference for token to be included in the report
				case_sensitive:bool=False, # frequencies for tokens with or without case preserved 
				normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
				page_size:int=PAGE_SIZE, # number of rows to return, if 0 returns all
				page_current:int=1, # current page, ignored if page_size is 0
				show_document_frequency:bool=False, # show document frequency in output
				exclude_tokens:list[str]=[], # exclude specific tokens from report results
				exclude_tokens_text:str = '', # text to explain which tokens have been excluded, will be added to the report notes
				restrict_tokens:list[str]=[], # restrict report to return results for a list of specific tokens
				restrict_tokens_text:str = '', # text to explain which tokens are included, will be added to the report notes
				exclude_punctuation:bool=True # exclude punctuation tokens
				) -> Result: # return a Result object with the frequency table
	""" Get keywords for the corpus. """
	if self.keyness_ is None:
		raise ValueError("Reference corpus is not set. Use 'set_reference_corpus' to set the reference corpus.")
	return self.keyness_.keywords(effect_size_measure=effect_size_measure,
									statistical_significance_measure=statistical_significance_measure,
									order=order,
									order_descending=order_descending,
									statistical_significance_cut=statistical_significance_cut,
									apply_bonferroni=apply_bonferroni,
									min_document_frequency=min_document_frequency,
									min_document_frequency_reference=min_document_frequency_reference,
									min_frequency=min_frequency,
									min_frequency_reference=min_frequency_reference,
									case_sensitive=case_sensitive,
									normalize_by=normalize_by,
									page_size=page_size,
									page_current=page_current,
									show_document_frequency=show_document_frequency,
									exclude_tokens=exclude_tokens,
									exclude_tokens_text=exclude_tokens_text,
									restrict_tokens=restrict_tokens,
									restrict_tokens_text=restrict_tokens_text,
									exclude_punctuation=exclude_punctuation)

# %%
#| hide
# keyness "said" frequency 25,379

# %%
conc.keywords(statistical_significance_cut = 0.0001, min_document_frequency_reference = 5).display()
# Out:
# <div id="zilvabjvmc" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #zilvabjvmc table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #zilvabjvmc thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #zilvabjvmc p { margin: 0; padding: 0; }
#  #zilvabjvmc .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #zilvabjvmc .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #zilvabjvmc .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #zilvabjvmc .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #zilvabjvmc .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #zilvabjvmc .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #zilvabjvmc .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #zilvabjvmc .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #zilvabjvmc .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #zilvabjvmc .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #zilvabjvmc .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #zilvabjvmc .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #zilvabjvmc .gt_spanner_row { border-bottom-style: hidden; }
#  #zilvabjvmc .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #zilvabjvmc .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #zilvabjvmc .gt_from_md> :first-child { margin-top: 0; }
#  #zilvabjvmc .gt_from_md> :last-child { margin-bottom: 0; }
#  #zilvabjvmc .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #zilvabjvmc .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #zilvabjvmc .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #zilvabjvmc .gt_row_group_first td { border-top-width: 2px; }
#  #zilvabjvmc .gt_row_group_first th { border-top-width: 2px; }
#  #zilvabjvmc .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #zilvabjvmc .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #zilvabjvmc .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #zilvabjvmc .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #zilvabjvmc .gt_left { text-align: left; }
#  #zilvabjvmc .gt_center { text-align: center; }
#  #zilvabjvmc .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #zilvabjvmc .gt_font_normal { font-weight: normal; }
#  #zilvabjvmc .gt_font_bold { font-weight: bold; }
#  #zilvabjvmc .gt_font_italic { font-style: italic; }
#  #zilvabjvmc .gt_super { font-size: 65%; }
#  #zilvabjvmc .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #zilvabjvmc .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_title gt_font_normal">Keywords</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Target corpus: Reuters Corpus, Reference corpus: Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency Reference">Frequency Reference</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope=

# %%
#| export
@patch
def collocates(self: Conc, 
				token_str:str, # Token to search for
				effect_size_measure:str = 'logdice', # statistical measure to use for collocation calculation: logdice, mutual_information
				statistical_significance_measure:str = 'log_likelihood', # statistical significance measure to use, currently only 'log_likelihood' is supported
				order:str|None = None, # default of None orders by collocation_measure, results can also be ordered by: collocate_frequency, frequency, log_likelihood
				order_descending:bool = True, # order is descending or ascending
				statistical_significance_cut: float|None = None, # statistical significance p-value to filter results, e.g. 0.05 or 0.01 or 0.001 - ignored if None or 0
				apply_bonferroni:bool = False, # apply Bonferroni correction to the statistical significance cut-off
				context_length:int|tuple[int, int]=5, # Window size per side in tokens - if an int (e.g. 5) context lengths on left and right will be the same, for independent control of left and right context length pass a tuple (context_length_left, context_left_right) (e.g. (0, 5)) 
				min_collocate_frequency:int=5, # Minimum count of collocates
				page_size:int=PAGE_SIZE, # number of rows to return, if 0 returns all
				page_current:int=1, # current page, ignored if page_size is 0
				exclude_punctuation:bool=True # exclude punctuation tokens				
				) -> Result:

	""" Report collocates for a given token string. """

	return self.collocates_.collocates(token_str, 
										effect_size_measure=effect_size_measure, 
										statistical_significance_measure=statistical_significance_measure, 
										order=order, 
										order_descending=order_descending, 
										statistical_significance_cut=statistical_significance_cut, 
										apply_bonferroni=apply_bonferroni, 
										context_length=context_length, 
										min_collocate_frequency=min_collocate_frequency, 
										page_size=page_size, 
										page_current=page_current,
										exclude_punctuation=exclude_punctuation)

# %%
#| hide
# collocates "said" frequency 25,379
# with context_length = (0, 1) and exclude_punctuation False and "the company" said collocate frequency is 1,173

# %%
conc.collocates('the company', context_length = (0, 1), exclude_punctuation = False).display()
# Out:
# <div id="hwojtzhxdd" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #hwojtzhxdd table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #hwojtzhxdd thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #hwojtzhxdd p { margin: 0; padding: 0; }
#  #hwojtzhxdd .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #hwojtzhxdd .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #hwojtzhxdd .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #hwojtzhxdd .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #hwojtzhxdd .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hwojtzhxdd .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hwojtzhxdd .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hwojtzhxdd .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #hwojtzhxdd .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #hwojtzhxdd .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #hwojtzhxdd .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #hwojtzhxdd .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #hwojtzhxdd .gt_spanner_row { border-bottom-style: hidden; }
#  #hwojtzhxdd .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #hwojtzhxdd .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #hwojtzhxdd .gt_from_md> :first-child { margin-top: 0; }
#  #hwojtzhxdd .gt_from_md> :last-child { margin-bottom: 0; }
#  #hwojtzhxdd .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #hwojtzhxdd .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #hwojtzhxdd .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #hwojtzhxdd .gt_row_group_first td { border-top-width: 2px; }
#  #hwojtzhxdd .gt_row_group_first th { border-top-width: 2px; }
#  #hwojtzhxdd .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #hwojtzhxdd .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hwojtzhxdd .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #hwojtzhxdd .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #hwojtzhxdd .gt_left { text-align: left; }
#  #hwojtzhxdd .gt_center { text-align: center; }
#  #hwojtzhxdd .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #hwojtzhxdd .gt_font_normal { font-weight: normal; }
#  #hwojtzhxdd .gt_font_bold { font-weight: bold; }
#  #hwojtzhxdd .gt_font_italic { font-style: italic; }
#  #hwojtzhxdd .gt_super { font-size: 65%; }
#  #hwojtzhxdd .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #hwojtzhxdd .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_title gt_font_normal">Collocates of &quot;the company&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Collocate Frequency">Collocate Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Logdice">Logdice</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Log Likelihood">Log Likelihood</th

# %%
#| hide
import nbdev; nbdev.nbdev_export()
