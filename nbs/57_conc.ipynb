# %% [markdown]
# # conc
#
# > An interface to create Conc reports for corpus linguistic analysis of frequency, concordances, ngrams, keyness, and collocation.

# %%
#| default_exp conc

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
from __future__ import annotations
import time
from fastcore.basics import patch

# %%
#| export
from conc.result import Result
from conc.core import PAGE_SIZE, logger
from conc.corpus import Corpus
from conc.frequency import Frequency
from conc.ngrams import Ngrams
from conc.concordance import Concordance
from conc.keyness import Keyness
from conc.collocates import Collocates

# %%
#| hide
from conc.core import set_logger_state

# %%
#| hide
import os

# %%
#| hide
source_path = f'{os.environ.get("HOME")}/data/'
save_path = f'{os.environ.get("HOME")}/data/conc-test-corpora/'

path_to_toy_corpus = f'{save_path}toy.corpus'
path_to_brown_corpus = f'{save_path}brown.corpus'
path_to_reuters_corpus = f'{save_path}reuters.corpus'

# %%
#| export
class Conc:
	"""Unified interface to Conc reporting for analysis of frequency, ngrams, concordances, keyness, and collocates."""
	
	def __init__(self, 
				corpus # Corpus instance
				):
		# information about corpus
		self.corpus = corpus
		self.frequency_ = Frequency(corpus)
		self.ngrams_ = Ngrams(corpus)
		self.concordance_ = Concordance(corpus)
		self.keyness_ = None
		self.collocates_ = Collocates(corpus)

# %%
# load (or build) a corpus
reuters = Corpus('reuters').load(path_to_reuters_corpus)

# %%
#get a summary
reuters.summary()
# Out:
# <div id="bobrpnwluc" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #bobrpnwluc table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #bobrpnwluc thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #bobrpnwluc p { margin: 0; padding: 0; }
#  #bobrpnwluc .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #bobrpnwluc .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #bobrpnwluc .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #bobrpnwluc .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #bobrpnwluc .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #bobrpnwluc .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #bobrpnwluc .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #bobrpnwluc .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #bobrpnwluc .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #bobrpnwluc .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #bobrpnwluc .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #bobrpnwluc .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #bobrpnwluc .gt_spanner_row { border-bottom-style: hidden; }
#  #bobrpnwluc .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #bobrpnwluc .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #bobrpnwluc .gt_from_md> :first-child { margin-top: 0; }
#  #bobrpnwluc .gt_from_md> :last-child { margin-bottom: 0; }
#  #bobrpnwluc .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #bobrpnwluc .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #bobrpnwluc .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #bobrpnwluc .gt_row_group_first td { border-top-width: 2px; }
#  #bobrpnwluc .gt_row_group_first th { border-top-width: 2px; }
#  #bobrpnwluc .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #bobrpnwluc .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #bobrpnwluc .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #bobrpnwluc .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #bobrpnwluc .gt_left { text-align: left; }
#  #bobrpnwluc .gt_center { text-align: center; }
#  #bobrpnwluc .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #bobrpnwluc .gt_font_normal { font-weight: normal; }
#  #bobrpnwluc .gt_font_bold { font-weight: bold; }
#  #bobrpnwluc .gt_font_italic { font-style: italic; }
#  #bobrpnwluc .gt_super { font-size: 65%; }
#  #bobrpnwluc .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #bobrpnwluc .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_title gt_font_normal">Corpus Summary</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="2" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border"></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Attribute">Attribute</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Value">Value</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_left">Name</td>
#     <td class="gt_row gt_left">Reuters Corpus</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_left">Description</td>
#     <td class="gt_row gt_left">Reuters corpus (Reuters-21578, Distribution 1.0). "The copyright for the text of newswire articles and Reuters annotations in the Reuters-21578 collection resides with Reuters Ltd. Reuters Ltd. and Carnegie Group, Inc. have agreed to allow the free distribution of this data *for research purposes only*. If you publish results ba

# %%
# create a Conc report instance for the corpus
conc = Conc(reuters)

# %%
#| export
@patch
def frequencies(self: Conc,
				case_sensitive:bool=False, # frequencies for tokens with or without case preserved 
				normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
				page_size:int=PAGE_SIZE, # number of rows to return, if 0 returns all
				page_current:int=1, # current page, ignored if page_size is 0
				show_token_id:bool=False, # show token_id in output
				show_document_frequency:bool=False, # show document frequency in output
				exclude_tokens:list[str]=[], # exclude specific tokens from frequency report, can be used to remove stopwords
				exclude_tokens_text:str = '', # text to explain which tokens have been excluded, will be added to the report notes
				restrict_tokens:list[str]=[], # restrict frequency report to return frequencies for a list of specific tokens
				restrict_tokens_text:str = '', # text to explain which tokens are included, will be added to the report notes
				exclude_punctuation:bool=True # exclude punctuation tokens
				) -> Result: # return a Result object with the frequency table
	""" Report frequent tokens. """
	return self.frequency_.frequencies(case_sensitive=case_sensitive,
										normalize_by=normalize_by,
										page_size=page_size,
										page_current=page_current,
										show_token_id=show_token_id,
										show_document_frequency=show_document_frequency,
										exclude_tokens=exclude_tokens,
										exclude_tokens_text=exclude_tokens_text,
										restrict_tokens=restrict_tokens,
										restrict_tokens_text=restrict_tokens_text,
										exclude_punctuation=exclude_punctuation)

# %%
#| hide
# said mentioned 25379

# %%
conc.frequencies(normalize_by=10000).display()
# Out:
# <div id="ywgngxmsvh" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ywgngxmsvh table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ywgngxmsvh thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ywgngxmsvh p { margin: 0; padding: 0; }
#  #ywgngxmsvh .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ywgngxmsvh .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ywgngxmsvh .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #ywgngxmsvh .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #ywgngxmsvh .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ywgngxmsvh .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ywgngxmsvh .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ywgngxmsvh .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ywgngxmsvh .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ywgngxmsvh .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ywgngxmsvh .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ywgngxmsvh .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ywgngxmsvh .gt_spanner_row { border-bottom-style: hidden; }
#  #ywgngxmsvh .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ywgngxmsvh .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ywgngxmsvh .gt_from_md> :first-child { margin-top: 0; }
#  #ywgngxmsvh .gt_from_md> :last-child { margin-bottom: 0; }
#  #ywgngxmsvh .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ywgngxmsvh .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ywgngxmsvh .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ywgngxmsvh .gt_row_group_first td { border-top-width: 2px; }
#  #ywgngxmsvh .gt_row_group_first th { border-top-width: 2px; }
#  #ywgngxmsvh .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #ywgngxmsvh .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ywgngxmsvh .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ywgngxmsvh .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ywgngxmsvh .gt_left { text-align: left; }
#  #ywgngxmsvh .gt_center { text-align: center; }
#  #ywgngxmsvh .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ywgngxmsvh .gt_font_normal { font-weight: normal; }
#  #ywgngxmsvh .gt_font_bold { font-weight: bold; }
#  #ywgngxmsvh .gt_font_italic { font-style: italic; }
#  #ywgngxmsvh .gt_super { font-size: 65%; }
#  #ywgngxmsvh .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ywgngxmsvh .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Frequencies of word tokens, Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the</td>
#     <td class="gt_row gt_right">69,263</td>
#     <td class="gt_row gt_right">495.17</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt

# %%
#| export
@patch
def ngrams(self: Conc, 
		   token_str: str, # token string to get ngrams for 
		   ngram_length:int = 2, # length of ngram
		   ngram_token_position: str = 'LEFT', # specify if token sequence is on LEFT or RIGHT (support for ngrams with token in middle of sequence is in-development))
		   normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
		   page_size:int = PAGE_SIZE, # number of results to display per results page 
		   page_current:int = 1, # current page of results
		   show_all_columns:bool = False, # return raw df with all columns or just ngram and frequency
		   exclude_punctuation:bool=True, # do not return ngrams with punctuation tokens
		   use_cache:bool = True # retrieve the results from cache if available
		   ) -> Result: # return a Result object with ngram data
	""" Report ngram frequencies containing a token string. """

	return self.ngrams_.ngrams(token_str, 
							ngram_length=ngram_length, 
							ngram_token_position=ngram_token_position, 
							normalize_by=normalize_by,
							page_size=page_size, 
							page_current=page_current, 
							show_all_columns=show_all_columns, 
							exclude_punctuation=exclude_punctuation,
							use_cache=use_cache)

# %%
#| hide
# said mentioned 25,379 from above - matches count 25,379 for bigrams ... 
# conc.ngrams(token_str = 'said', ngram_length = 2, ngram_token_position = 'LEFT', exclude_punctuation = False, page_size = 5).display()
# if change to trigrams - get different count 25,355 - this is due to EOF removal
set_logger_state('verbose')
conc.ngrams(token_str = 'said', ngram_length = 3, ngram_token_position = 'RIGHT', exclude_punctuation = True, page_size = 5).display()
set_logger_state('quiet')
# the company said ngram shown as 1,173
# Out:
# 2025-06-10 10:54:21 - INFO - _init_token_arrays - Created tokens_array in 0.015 seconds
# 2025-06-10 10:54:21 - INFO - _init_token_arrays - Created tokens_lookup in 0.006 seconds
# 2025-06-10 10:54:21 - INFO - _init_token_arrays - Created tokens_sort_order in 0.006 seconds
# 2025-06-10 10:54:21 - INFO - tokenize - Tokenization time: 0.02980 seconds
# 2025-06-10 10:54:21 - INFO - get_token_positions - Token indexing (25379) time: 0.01357 seconds
# 2025-06-10 10:54:21 - INFO - ngrams - Generating ngrams results
# 2025-06-10 10:54:21 - INFO - get_tokens_in_context - Context tokens collected: (3, 25379)
# 2025-06-10 10:54:21 - INFO - get_tokens_in_context - Context retrieved in 0.06 seconds.
# 2025-06-10 10:54:21 - DEBUG - _get_ngrams - Ngrams shape prior to EOF removal (3, 25379)
# 2025-06-10 10:54:21 - DEBUG - _get_ngrams - Ngrams shape after EOF removal (3, 25355)
# 2025-06-10 10:54:21 - INFO - _get_ngrams - Ngrams (12707) retrieval time: 0.06519 seconds
# 2025-06-10 10:54:21 - INFO - ngrams - Ngrams report time: 0.08389 seconds
# <div id="ztdzpoidaj" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ztdzpoidaj table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ztdzpoidaj thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ztdzpoidaj p { margin: 0; padding: 0; }
#  #ztdzpoidaj .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ztdzpoidaj .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ztdzpoidaj .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #ztdzpoidaj .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #ztdzpoidaj .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ztdzpoidaj .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ztdzpoidaj .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ztdzpoidaj .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ztdzpoidaj .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ztdzpoidaj .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ztdzpoidaj .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ztdzpoidaj .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ztdzpoidaj .gt_spanner_row { border-bottom-style: hidden; }
#  #ztdzpoidaj .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ztdzpoidaj .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #ztdzpoidaj .gt_from_md> :first-child { margin-top: 0; }
#  #ztdzpoidaj .gt_from_md> :last-child { margin-bottom: 0; }
#  #ztdzpoidaj .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #ztdzpoidaj .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #ztdzpoidaj .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ztdzpoidaj .gt_row_group_first td { border-top-width: 2px; }
#  #ztdzpoidaj .gt_row_group_first th { border-top-width: 2px; }
#  #ztdzpoidaj .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #ztdzpoidaj .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #ztdzpoidaj .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ztdzpoidaj .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ztdzpoidaj .gt_left { text-align: left; }
#  #ztdzpoidaj .gt_center { text-align: center; }
#  #ztdzpoidaj .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ztdzpoidaj .gt_font_normal { font-weight: normal; }
#  #ztdzpoidaj .gt_font_bold { font-weight: bold; }
#  #ztdzpoidaj .gt_font_italic { font-style: italic; }
#  #ztdzpoidaj .gt_super { font-size: 65%; }
#  #ztdzpoidaj .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ztdzpoidaj .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngrams for &quot;said&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_r

# %%
conc.ngrams(token_str = 'said', ngram_length = 3, ngram_token_position = 'RIGHT', exclude_punctuation = True).display()
# Out:
# <div id="hpitrdkkhy" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #hpitrdkkhy table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #hpitrdkkhy thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #hpitrdkkhy p { margin: 0; padding: 0; }
#  #hpitrdkkhy .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #hpitrdkkhy .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #hpitrdkkhy .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #hpitrdkkhy .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #hpitrdkkhy .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hpitrdkkhy .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hpitrdkkhy .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #hpitrdkkhy .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #hpitrdkkhy .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #hpitrdkkhy .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #hpitrdkkhy .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #hpitrdkkhy .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #hpitrdkkhy .gt_spanner_row { border-bottom-style: hidden; }
#  #hpitrdkkhy .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #hpitrdkkhy .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #hpitrdkkhy .gt_from_md> :first-child { margin-top: 0; }
#  #hpitrdkkhy .gt_from_md> :last-child { margin-bottom: 0; }
#  #hpitrdkkhy .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #hpitrdkkhy .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #hpitrdkkhy .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #hpitrdkkhy .gt_row_group_first td { border-top-width: 2px; }
#  #hpitrdkkhy .gt_row_group_first th { border-top-width: 2px; }
#  #hpitrdkkhy .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #hpitrdkkhy .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #hpitrdkkhy .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #hpitrdkkhy .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #hpitrdkkhy .gt_left { text-align: left; }
#  #hpitrdkkhy .gt_center { text-align: center; }
#  #hpitrdkkhy .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #hpitrdkkhy .gt_font_normal { font-weight: normal; }
#  #hpitrdkkhy .gt_font_bold { font-weight: bold; }
#  #hpitrdkkhy .gt_font_italic { font-style: italic; }
#  #hpitrdkkhy .gt_super { font-size: 65%; }
#  #hpitrdkkhy .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #hpitrdkkhy .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngrams for &quot;said&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_r

# %%
#| export
@patch
def ngram_frequencies(self: Conc, 
                ngram_length:int=2, # length of ngram
                case_sensitive:bool=False, # frequencies for tokens lowercased or with case preserved
				normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
				page_size:int=PAGE_SIZE, # number of rows to return
				page_current:int=1, # current page
				exclude_punctuation:bool=True # exclude ngrams containing punctuation tokens
				) -> Result: # return a Result object with the frequency table
    """ Report frequent ngrams. """
    return self.ngrams_.ngram_frequencies(ngram_length=ngram_length,
                                    case_sensitive=case_sensitive,
                                    normalize_by=normalize_by,
                                    page_size=page_size,
                                    page_current=page_current,
                                    exclude_punctuation=exclude_punctuation)

# %%
#| hide
# "the company said" = 1,173 - matches above count
conc.ngram_frequencies(ngram_length = 3, case_sensitive = False, exclude_punctuation = True, page_size = 10).display()
# Out:
# <div id="dblegqotwv" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #dblegqotwv table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #dblegqotwv thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #dblegqotwv p { margin: 0; padding: 0; }
#  #dblegqotwv .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #dblegqotwv .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #dblegqotwv .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #dblegqotwv .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #dblegqotwv .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dblegqotwv .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #dblegqotwv .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dblegqotwv .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #dblegqotwv .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #dblegqotwv .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #dblegqotwv .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #dblegqotwv .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #dblegqotwv .gt_spanner_row { border-bottom-style: hidden; }
#  #dblegqotwv .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #dblegqotwv .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #dblegqotwv .gt_from_md> :first-child { margin-top: 0; }
#  #dblegqotwv .gt_from_md> :last-child { margin-bottom: 0; }
#  #dblegqotwv .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #dblegqotwv .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #dblegqotwv .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #dblegqotwv .gt_row_group_first td { border-top-width: 2px; }
#  #dblegqotwv .gt_row_group_first th { border-top-width: 2px; }
#  #dblegqotwv .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #dblegqotwv .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #dblegqotwv .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #dblegqotwv .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #dblegqotwv .gt_left { text-align: left; }
#  #dblegqotwv .gt_center { text-align: center; }
#  #dblegqotwv .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #dblegqotwv .gt_font_normal { font-weight: normal; }
#  #dblegqotwv .gt_font_bold { font-weight: bold; }
#  #dblegqotwv .gt_font_italic { font-style: italic; }
#  #dblegqotwv .gt_super { font-size: 65%; }
#  #dblegqotwv .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #dblegqotwv .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngram Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_right">2</t

# %%
conc.ngram_frequencies(ngram_length = 3, case_sensitive = False, exclude_punctuation = True, page_current = 1).display()
# Out:
# <div id="jmoavgdjlc" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #jmoavgdjlc table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #jmoavgdjlc thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #jmoavgdjlc p { margin: 0; padding: 0; }
#  #jmoavgdjlc .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #jmoavgdjlc .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #jmoavgdjlc .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #jmoavgdjlc .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #jmoavgdjlc .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jmoavgdjlc .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jmoavgdjlc .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jmoavgdjlc .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #jmoavgdjlc .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #jmoavgdjlc .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #jmoavgdjlc .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #jmoavgdjlc .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #jmoavgdjlc .gt_spanner_row { border-bottom-style: hidden; }
#  #jmoavgdjlc .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #jmoavgdjlc .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #jmoavgdjlc .gt_from_md> :first-child { margin-top: 0; }
#  #jmoavgdjlc .gt_from_md> :last-child { margin-bottom: 0; }
#  #jmoavgdjlc .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #jmoavgdjlc .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #jmoavgdjlc .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #jmoavgdjlc .gt_row_group_first td { border-top-width: 2px; }
#  #jmoavgdjlc .gt_row_group_first th { border-top-width: 2px; }
#  #jmoavgdjlc .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #jmoavgdjlc .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #jmoavgdjlc .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #jmoavgdjlc .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #jmoavgdjlc .gt_left { text-align: left; }
#  #jmoavgdjlc .gt_center { text-align: center; }
#  #jmoavgdjlc .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #jmoavgdjlc .gt_font_normal { font-weight: normal; }
#  #jmoavgdjlc .gt_font_bold { font-weight: bold; }
#  #jmoavgdjlc .gt_font_italic { font-style: italic; }
#  #jmoavgdjlc .gt_super { font-size: 65%; }
#  #jmoavgdjlc .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #jmoavgdjlc .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Ngram Frequencies</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Ngram">Ngram</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">1</td>
#     <td class="gt_row gt_left">the company said</td>
#     <td class="gt_row gt_right">1,173</td>
#     <td class="gt_row gt_right">8.39</td>
#   </tr>
#   <tr>
#     <td class="gt_row gt_right">2</t

# %%
#| export
@patch
def concordance(self: Conc, 
				token_str: str, # token string to get concordance for 
				context_length:int = 5, # number of words to show on left and right of token string
				order:str='1R2R3R', # order of sort columns
				page_size:int=PAGE_SIZE, # number of results to display per results page
				page_current:int=1, # current page of results
				show_all_columns:bool = False, # df with all columns or just essentials
				use_cache:bool = True # retrieve the results from cache if available
				) -> Result: # concordance report results
	""" Report concordance for a token string. """
	return self.concordance_.concordance(token_str, context_length=context_length, order=order, page_size=page_size, page_current=page_current, show_all_columns=show_all_columns, use_cache=use_cache)

# %%
#| hide
# Total Concordance Lines for "said" is correct - 25379
# "the company said" 1173

# %%
conc.concordance('the company said', context_length = 5, order='1R2R3R').display()
# Out:
# <div id="nvkanohmbh" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #nvkanohmbh table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #nvkanohmbh thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #nvkanohmbh p { margin: 0; padding: 0; }
#  #nvkanohmbh .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #nvkanohmbh .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #nvkanohmbh .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #nvkanohmbh .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #nvkanohmbh .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #nvkanohmbh .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #nvkanohmbh .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #nvkanohmbh .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #nvkanohmbh .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #nvkanohmbh .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #nvkanohmbh .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #nvkanohmbh .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #nvkanohmbh .gt_spanner_row { border-bottom-style: hidden; }
#  #nvkanohmbh .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #nvkanohmbh .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #nvkanohmbh .gt_from_md> :first-child { margin-top: 0; }
#  #nvkanohmbh .gt_from_md> :last-child { margin-bottom: 0; }
#  #nvkanohmbh .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #nvkanohmbh .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #nvkanohmbh .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #nvkanohmbh .gt_row_group_first td { border-top-width: 2px; }
#  #nvkanohmbh .gt_row_group_first th { border-top-width: 2px; }
#  #nvkanohmbh .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #nvkanohmbh .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #nvkanohmbh .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #nvkanohmbh .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #nvkanohmbh .gt_left { text-align: left; }
#  #nvkanohmbh .gt_center { text-align: center; }
#  #nvkanohmbh .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #nvkanohmbh .gt_font_normal { font-weight: normal; }
#  #nvkanohmbh .gt_font_bold { font-weight: bold; }
#  #nvkanohmbh .gt_font_italic { font-style: italic; }
#  #nvkanohmbh .gt_super { font-size: 65%; }
#  #nvkanohmbh .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #nvkanohmbh .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal">Concordance for &quot;the company said&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus, Context tokens: 5, Order: 1R2R3R</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Document Id">Document Id</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Left">Left</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Node">Node</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Right">Right</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td class="gt_row gt_right">2,744</td>
#     <td class="gt_row gt_right">through a tender offer .</td>
#     <td class="gt_row gt_left">The company said</td>
#     <td class="gt_row gt_left">" The n

# %%
#| export
@patch
def concordance_plot(self: Conc,
					 token_str: str,
					 page_size: int = 10):
	"""Display concordance plot."""
	return self.concordance_.concordance_plot(token_str, 
										   page_size=page_size)

# %%
#| hide
conc.concordance_plot('the company said', page_size=10)
# Out:
# IntSlider(value=1, description='Page', layout=Layout(margin='10px 0 10px 0', width='600px'), max=92, min=1)
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'hovertext': '1.53 billion in 1985 . The company said it had been',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5eff8aa5-dfe1-43a1-9db0-239d040d6ba8',
#               'x': [30.42071197411003, 30.42071197411003],
#               'xaxis': 'x',
#               'y': [0, 1],
#               'yaxis': 'y'},
#              {'hoverinfo': 'text',
#               'hovertext': 'stg profit in 1985 . The company said in a statement',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b85a67be-749a-4740-b76f-e088cda8ddea',
#               'x': [33.86243386243386, 33.86243386243386],
#               'xaxis': 'x2',
#               'y': [0, 1],
#               'yaxis': 'y2'},
#              {'hoverinfo': 'text',
#               'hovertext': 'lire reported in 1985 . The company said in a statement',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3f824068-9a67-4ebb-8940-0236ec6cf205',
#               'x': [34.862385321100916, 34.862385321100916],
#               'xaxis': 'x3',
#               'y': [0, 1],
#               'yaxis': 'y3'},
#              {'hoverinfo': 'text',
#               'hovertext': '24.1 billion in 1985 . The company said 1986 dividend ,',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f3b628e5-cf09-4c5e-8aee-c174193ceb9e',
#               'x': [44.06779661016949, 44.06779661016949],
#               'xaxis': 'x4',
#               'y': [0, 1],
#               'yaxis': 'y4'},
#              {'hoverinfo': 'text',
#               'hovertext': 'In a newspaper advertisement , the company said the tender and',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8b186393-1870-4887-b7eb-f5c33cc19f16',
#               'x': [42.2680412371134, 42.2680412371134],
#               'xaxis': 'x5',
#               'y': [0, 1],
#               'yaxis': 'y5'},
#              {'hoverinfo': 'text',
#               'hovertext': 'a scaleup of production . The company said research spending is',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c2cea39f-8b32-4bab-9065-eb8da6d10874',
#               'x': [28.104575163398692, 28.104575163398692],
#               'xaxis': 'x6',
#               'y': [0, 1],
#               'yaxis': 'y6'},
#              {'hoverinfo': 'text',
#               'hovertext': 'the first quarter 1986 . The company said demand for its',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3136da87-47f3-4fc4-9d9b-dd6431eca749',
#               'x': [60.19900497512438, 60.19900497512438],
#               'xaxis': 'x7',
#               'y': [0, 1],
#               'yaxis': 'y7'},
#              {'hoverinfo': 'text',
#               'hovertext': 'transaction were not disclosed , the company said . The transaction',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f8a95bd9-10f9-498e-98f1-201ff3ed7bc8',
#               'x': [41.41414141414141, 41.41414141414141],
#               'xaxis': 'x8',
#               'y': [0, 1],
#               'yaxis': 'y8'},
#              {'hoverinfo': 'text',
#               'hovertext': 'the last three months , the company said .',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1912f8d9-3191-4d12-ad95-496a6ab6ebda',
#               'x': [95.8904109589041, 95.8904109589041],
#               'xaxis': 'x9',
#               'y': [0, 1],
#               'yaxis': 'y9'},
#              {'hoverinfo': 'text',
#               'hovertext': 'of National Park , N.J. The company said it bought alarm',
#               'line': {'color': 'black', 'width': 2},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3a4c020a-735b-4009-983f-22cc7717ab3d',
#               'x': [64.1891891891892, 64.1891891891892],
#               'xaxis': 'x10',
#               'y': [0, 1],
#               'yaxis': 'y10'}],
#     'layout': {'annotations': [{'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 13',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 23',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y2 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y2 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 50',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y3 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y3 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 52',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y4 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y4 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 54',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y5 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y5 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 55',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y6 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y6 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 76',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y7 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y7 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 77',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y8 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y8 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 102',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y9 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y9 domain'},
#                                {'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 12},
#                                 'showarrow': False,
#                                 'text': 'Doc 107',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.65,
#                                 'yanchor': 'middle',
#                                 'yref': 'y10 domain'},
#                                {'font': {'color': 'gray',
#                                          'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                                          'size': 11},
#                                 'showarrow': False,
#                                 'text': '1 line',
#                                 'x': -0.03,
#                                 'xanchor': 'right',
#                                 'xref': 'paper',
#                                 'y': 0.22,
#                                 'yanchor': 'middle',
#                                 'yref': 'y10 domain'}],
#                'font': {'family': ("'Segoe UI', Roboto, Oxygen, Ub" ... "roid Sans', Arial, sans-serif;"),
#                         'size': 12},
#                'height': 500,
#                'margin': {'b': 20, 'l': 80, 'r': 20, 't': 40},
#                'shapes': [{'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x2',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y2'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x3',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y3'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x4',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y4'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x5',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y5'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x6',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y6'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x7',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y7'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x8',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y8'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x9',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y9'},
#                           {'fillcolor': 'gray',
#                            'layer': 'below',
#                            'line': {'color': 'black', 'width': 1},
#                            'opacity': 0.08,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 100,
#                            'xref': 'x10',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y10'}],
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Concordance Plot for "the company said"', 'x': 0.5},
#                'width': 600,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis10': {'anchor': 'y10', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis4': {'anchor': 'y4', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis5': {'anchor': 'y5', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis6': {'anchor': 'y6', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis7': {'anchor': 'y7', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis8': {'anchor': 'y8', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'xaxis9': {'anchor': 'y9', 'domain': [0.0, 1.0], 'fixedrange': True, 'range': [0, 100], 'visible': False},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.9450000000000001, 1.0],
#                          'fixedrange': True,
#                          'range': [0, 1],
#                          'visible': False},
#                'yaxis10': {'anchor': 'x10',
#                            'domain': [0.0, 0.05500000000000001],
#                            'fixedrange': True,
#                            'range': [0, 1],
#                            'visible': False},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.8400000000000001, 0.8950000000000001],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False},
#                'yaxis3': {'anchor': 'x3',
#                           'domain': [0.7350000000000001, 0.7900000000000001],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False},
#                'yaxis4': {'anchor': 'x4',
#                           'domain': [0.6300000000000001, 0.6850000000000002],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False},
#                'yaxis5': {'anchor': 'x5',
#                           'domain': [0.525, 0.5800000000000001],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False},
#                'yaxis6': {'anchor': 'x6',
#                           'domain': [0.42000000000000004, 0.47500000000000003],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False},
#                'yaxis7': {'anchor': 'x7',
#                           'domain': [0.31500000000000006, 0.37000000000000005],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False},
#                'yaxis8': {'anchor': 'x8',
#                           'domain': [0.21000000000000002, 0.265],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False},
#                'yaxis9': {'anchor': 'x9',
#                           'domain': [0.10500000000000001, 0.16000000000000003],
#                           'fixedrange': True,
#                           'range': [0, 1],
#                           'visible': False}}
# })
# HTML(value="<div style='text-align: left; font-size: 12px; color: black; margin-left: 80px;margin-bottom:10px;…

# %%
#| export
@patch
def set_reference_corpus(self: Conc, 
                    corpus: Corpus  # Reference corpus
                    ) -> None:
    """ Set a reference corpus for keyness analysis. """
    self.keyness_ = Keyness(self.corpus, corpus)

# %%
# load a corpus as a reference corpus
brown = Corpus('brown').load(path_to_brown_corpus)

# set corpus as reference corpus
conc.set_reference_corpus(brown)

# %%
#| export
@patch
def keywords(self: Conc,
				effect_size_measure:str = 'log_ratio', # effect size measure to use, currently only 'log_ratio' is supported
				statistical_significance_measure:str = 'log_likelihood', # statistical significance measure to use, currently only 'log_likelihood' is supported
				order:str|None = None, # default of None orders by effect size measure, results can also be ordered by: frequency, frequency_reference, document_frequency, document_frequency_reference, log_likelihood
				order_descending:bool = True, # order is descending or ascending
				statistical_significance_cut: float|None = None, # statistical significance p-value to filter results, e.g. 0.05 or 0.01 or 0.001 - ignored if None or 0
				apply_bonferroni:bool = False, # apply Bonferroni correction to the statistical significance cut-off
				min_document_frequency: int = 0, # minimum document frequency in target for token to be included in the report
				min_document_frequency_reference: int = 0, # minimum document frequency in reference for token to be included in the report
				min_frequency: int = 0, # minimum frequency in target for token to be included in the report
				min_frequency_reference: int = 0, # minimum document frequency in reference for token to be included in the report
				case_sensitive:bool=False, # frequencies for tokens with or without case preserved 
				normalize_by:int=10000, # normalize frequencies by a number (e.g. 10000)
				page_size:int=PAGE_SIZE, # number of rows to return, if 0 returns all
				page_current:int=1, # current page, ignored if page_size is 0
				show_document_frequency:bool=False, # show document frequency in output
				exclude_tokens:list[str]=[], # exclude specific tokens from report results
				exclude_tokens_text:str = '', # text to explain which tokens have been excluded, will be added to the report notes
				restrict_tokens:list[str]=[], # restrict report to return results for a list of specific tokens
				restrict_tokens_text:str = '', # text to explain which tokens are included, will be added to the report notes
				exclude_punctuation:bool=True # exclude punctuation tokens
				) -> Result: # return a Result object with the frequency table
	""" Get keywords for the corpus. """
	if self.keyness_ is None:
		raise ValueError("Reference corpus is not set. Use 'set_reference_corpus' to set the reference corpus.")
	return self.keyness_.keywords(effect_size_measure=effect_size_measure,
									statistical_significance_measure=statistical_significance_measure,
									order=order,
									order_descending=order_descending,
									statistical_significance_cut=statistical_significance_cut,
									apply_bonferroni=apply_bonferroni,
									min_document_frequency=min_document_frequency,
									min_document_frequency_reference=min_document_frequency_reference,
									min_frequency=min_frequency,
									min_frequency_reference=min_frequency_reference,
									case_sensitive=case_sensitive,
									normalize_by=normalize_by,
									page_size=page_size,
									page_current=page_current,
									show_document_frequency=show_document_frequency,
									exclude_tokens=exclude_tokens,
									exclude_tokens_text=exclude_tokens_text,
									restrict_tokens=restrict_tokens,
									restrict_tokens_text=restrict_tokens_text,
									exclude_punctuation=exclude_punctuation)

# %%
#| hide
# keyness "said" frequency 25,379

# %%
conc.keywords(statistical_significance_cut = 0.0001, min_document_frequency_reference = 5).display()
# Out:
# <div id="wfnpjshart" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #wfnpjshart table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #wfnpjshart thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #wfnpjshart p { margin: 0; padding: 0; }
#  #wfnpjshart .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #wfnpjshart .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #wfnpjshart .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #wfnpjshart .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #wfnpjshart .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wfnpjshart .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #wfnpjshart .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wfnpjshart .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #wfnpjshart .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #wfnpjshart .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #wfnpjshart .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #wfnpjshart .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #wfnpjshart .gt_spanner_row { border-bottom-style: hidden; }
#  #wfnpjshart .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #wfnpjshart .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #wfnpjshart .gt_from_md> :first-child { margin-top: 0; }
#  #wfnpjshart .gt_from_md> :last-child { margin-bottom: 0; }
#  #wfnpjshart .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #wfnpjshart .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #wfnpjshart .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #wfnpjshart .gt_row_group_first td { border-top-width: 2px; }
#  #wfnpjshart .gt_row_group_first th { border-top-width: 2px; }
#  #wfnpjshart .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #wfnpjshart .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #wfnpjshart .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #wfnpjshart .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #wfnpjshart .gt_left { text-align: left; }
#  #wfnpjshart .gt_center { text-align: center; }
#  #wfnpjshart .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #wfnpjshart .gt_font_normal { font-weight: normal; }
#  #wfnpjshart .gt_font_bold { font-weight: bold; }
#  #wfnpjshart .gt_font_italic { font-style: italic; }
#  #wfnpjshart .gt_super { font-size: 65%; }
#  #wfnpjshart .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #wfnpjshart .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_title gt_font_normal">Keywords</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="9" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Target corpus: Reuters Corpus, Reference corpus: Brown Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency Reference">Frequency Reference</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Normalized Frequency">Normalized Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope=

# %%
#| export
@patch
def collocates(self: Conc, 
				token_str:str, # Token to search for
				effect_size_measure:str = 'logdice', # statistical measure to use for collocation calculation: logdice, mutual_information
				statistical_significance_measure:str = 'log_likelihood', # statistical significance measure to use, currently only 'log_likelihood' is supported
				order:str|None = None, # default of None orders by collocation_measure, results can also be ordered by: collocate_frequency, frequency, log_likelihood
				order_descending:bool = True, # order is descending or ascending
				statistical_significance_cut: float|None = None, # statistical significance p-value to filter results, e.g. 0.05 or 0.01 or 0.001 - ignored if None or 0
				apply_bonferroni:bool = False, # apply Bonferroni correction to the statistical significance cut-off
				context_length:int|tuple[int, int]=5, # Window size per side in tokens - if an int (e.g. 5) context lengths on left and right will be the same, for independent control of left and right context length pass a tuple (context_length_left, context_left_right) (e.g. (0, 5)) 
				min_collocate_frequency:int=5, # Minimum count of collocates
				page_size:int=PAGE_SIZE, # number of rows to return, if 0 returns all
				page_current:int=1, # current page, ignored if page_size is 0
				exclude_punctuation:bool=True # exclude punctuation tokens				
				) -> Result:

	""" Report collocates for a given token string. """

	return self.collocates_.collocates(token_str, 
										effect_size_measure=effect_size_measure, 
										statistical_significance_measure=statistical_significance_measure, 
										order=order, 
										order_descending=order_descending, 
										statistical_significance_cut=statistical_significance_cut, 
										apply_bonferroni=apply_bonferroni, 
										context_length=context_length, 
										min_collocate_frequency=min_collocate_frequency, 
										page_size=page_size, 
										page_current=page_current,
										exclude_punctuation=exclude_punctuation)

# %%
#| hide
# collocates "said" frequency 25,379
# with context_length = (0, 1) and exclude_punctuation False and "the company" said collocate frequency is 1,173

# %%
conc.collocates('the company', context_length = (0, 1), exclude_punctuation = False).display()
# Out:
# <div id="rowyijipkj" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #rowyijipkj table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #rowyijipkj thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #rowyijipkj p { margin: 0; padding: 0; }
#  #rowyijipkj .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: 0; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #A8A8A8; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #A8A8A8; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #rowyijipkj .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #rowyijipkj .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }
#  #rowyijipkj .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }
#  #rowyijipkj .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rowyijipkj .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rowyijipkj .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rowyijipkj .gt_col_heading { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #rowyijipkj .gt_column_spanner_outer { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #rowyijipkj .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #rowyijipkj .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #rowyijipkj .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #rowyijipkj .gt_spanner_row { border-bottom-style: hidden; }
#  #rowyijipkj .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #rowyijipkj .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; vertical-align: middle; }
#  #rowyijipkj .gt_from_md> :first-child { margin-top: 0; }
#  #rowyijipkj .gt_from_md> :last-child { margin-bottom: 0; }
#  #rowyijipkj .gt_row { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: solid; border-top-width: 1px; border-top-color: #D3D3D3; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; overflow-x: hidden; }
#  #rowyijipkj .gt_stub { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; }
#  #rowyijipkj .gt_stub_row_group { color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #rowyijipkj .gt_row_group_first td { border-top-width: 2px; }
#  #rowyijipkj .gt_row_group_first th { border-top-width: 2px; }
#  #rowyijipkj .gt_striped { background-color: rgba(128,128,128,0.05); }
#  #rowyijipkj .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #D3D3D3; }
#  #rowyijipkj .gt_sourcenotes { color: #333333; background-color: #FFFFFF; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rowyijipkj .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #rowyijipkj .gt_left { text-align: left; }
#  #rowyijipkj .gt_center { text-align: center; }
#  #rowyijipkj .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #rowyijipkj .gt_font_normal { font-weight: normal; }
#  #rowyijipkj .gt_font_bold { font-weight: bold; }
#  #rowyijipkj .gt_font_italic { font-style: italic; }
#  #rowyijipkj .gt_super { font-size: 65%; }
#  #rowyijipkj .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #rowyijipkj .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_title gt_font_normal">Collocates of &quot;the company&quot;</td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Reuters Corpus</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Rank">Rank</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Token">Token</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Collocate Frequency">Collocate Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Frequency">Frequency</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Logdice">Logdice</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_right" rowspan="1" colspan="1" scope="col" id="Log Likelihood">Log Likelihood</th

# %%
#| hide
import nbdev; nbdev.nbdev_export()
